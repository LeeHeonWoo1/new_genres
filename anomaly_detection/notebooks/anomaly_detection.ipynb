# %% [markdown]
# ### Anomaly Detection
#
# 이상 탐지는 주어진 그룹의 예상 패턴에 부합하지 않는 데이터 포인트, 항목, 관찰 또는 이벤트를 식별하는 행위를 일컫는다. 이러한 이상은 매우 드물게 발생하지만 사이버 침입 또는 사기와 같은 크고 중대한 위협을 의미할 수 있다. 이상 탐지는 이러한 이상의 발생에 대한 탐지, 식별 및 예측에 대한 학습을 돕기 위해 행동 분석 및 다른 형태의 분석에서 많이 사용된다.
#
# ### 필요 Library Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from sklearn.decomposition import PCA

from sklearn.neighbors import LocalOutlierFactor
from sklearn.ensemble import IsolationForest

import warnings
warnings.filterwarnings("ignore")

import os

# %% [markdown]
# ### EDA 시작

# %%
df = pd.read_csv("../data/csv/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# 클래스 간 비율 확인

# %%
sns.countplot(df['Class'])
plt.show()
print(df['Class'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 sns.countplot(df['Class'])
# ----> 2 plt.show()
#       3 print(df['Class'].value_counts())
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\admin\miniconda3\envs\mynlp\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
# ...
