# %% [markdown]
# ### End-to-End NLP(EDA&ML) with Sentiment Analysis
#
# 해당 노트북에서는 BOW, tf-idf같은 문자 인코딩 기술이 어떻게 동작하는지 텍스트의 감성 분석을 통해 살펴본다.
#
# 사용할 데이터의 경우 감성에 대한 척도가 0, 1, 2, 3, 4로 라벨링 되어 있는 영화 리뷰 데이터이다.
#
# <center>
#
# |라벨링|정도|
# |:--:|:--:|
# |0|negative(부정)|
# |1|somehow negative(약간 부정)|
# |2|neutral(보통)|
# |3|somehow positive(약간 긍정)|
# |4|positive(긍정)|
#
# </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
import plotly.express as px
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk import ngrams

import string, re

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import warnings, os

# %% [markdown]
# 필요한 설정을 간단하게 진행한다.

# %%
pio.renderers.default = "notebook_connected"
warnings.filterwarnings('ignore')

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
train = pd.read_csv("./data/sentiment/train.tsv", sep="\t")
test = pd.read_csv("./data/sentiment/test.tsv", sep="\t")

# %% [markdown]
# ### EDA진행

# %%
train.shape, test.shape
# Out:
# ((156060, 4), (66292, 3))

# %%
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
test.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156062        8545  An intermittently pleasing but mostly routine ...
# 2    156063        8545                                                 An
# 3    156064        8545  intermittently pleasing but mostly routine effort
# 4    156065        8545         intermittently pleasing but mostly routine

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PhraseId    156060 non-null  int64
#  1   SentenceId  156060 non-null  int64
#  2   Phrase      156060 non-null  object
#  3   Sentiment   156060 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB

# %%
train.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# 데이터에 sentiment의 등급마다 설명을 추가해줍니다.

# %%
map_dict = {
    0 : "negative",
    1 : "somehow negative",
    2 : "neutral",
    3 : "somehow positive",
    4 : "positive"
}

train['sentiment_class'] = train['Sentiment'].map(map_dict)
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment   sentiment_class
# 0          1  somehow negative
# 1          2           neutral
# 2          2           neutral
# 3          2           neutral
# 4          2           neutral

# %% [markdown]
# `string.punctuation`을 활용하여 구두점을 제거합니다.
#
# - string.punctuation은 아래와 같은 특수문자들을 포함합니다.
#
# ```
# !"#$%&'()*+,-./:;<=>?@[\\]^_`{|}~
# ```

# %%
def remove_puncutation(text):
    return ''.join([x for x in text if x not in string.punctuation])

# %%
train['Phrase'] = train['Phrase'].apply(lambda x : remove_puncutation(x))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment   sentiment_class
# 0          1  somehow negative
# 1          2           neutral
# 2          2           neutral
# 3          2           neutral
# 4          2           neutral

# %% [markdown]
# 2개 이하의 문자로 이루어진 단어를 제거합니다.

# %%
def words_with_more_than_three_chars(text):
    return ' '.join([x for x in text.split() if len(x) > 3])

# %%
train['Phrase'] = train['Phrase'].apply(lambda x : words_with_more_than_three_chars(x))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage that what...
# 1         2           1  series escapades demonstrating adage that what...
# 2         3           1                                             series
# 3         4           1
# 4         5           1                                             series
#
#    Sentiment   sentiment_class
# 0          1  somehow negative
# 1          2           neutral
# 2          2           neutral
# 3          2           neutral
# 4          2           neutral

# %%
print(train.shape)
train.loc[train['Phrase']==''].shape
# Out:
# (156060, 5)
# (2129, 5)

# %%
train = train.loc[train['Phrase'] != '']

# %%
train.shape
# Out:
# (153931, 5)

# %% [markdown]
# ### 불용어 제거
#
# nltk에 내장되어 있는 stopwords를 적용하고, 제거합니다.

# %%
stopword = stopwords.words('english')
train['Phrase'] = train['Phrase'].apply(lambda x : ' '.join([word for word in x.split() if word not in stopword]))
train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage good goos...
# 1         2           1    series escapades demonstrating adage good goose
# 2         3           1                                             series
# 4         5           1                                             series
# 5         6           1           escapades demonstrating adage good goose
#
#    Sentiment   sentiment_class
# 0          1  somehow negative
# 1          2           neutral
# 2          2           neutral
# 4          2           neutral
# 5          2           neutral

# %% [markdown]
# ### 감성 카테고리 확인

# %%
train.groupby('Sentiment')['Sentiment'].count()
# Out:
# Sentiment
# 0     7057
# 1    27141
# 2    77773
# 3    32767
# 4     9193
# Name: Sentiment, dtype: int64

# %% [markdown]
# ### 타겟 클래스의 Distribution

# %%
data = train.groupby('sentiment_class')['sentiment_class'].count()

fig = px.bar(y = data, x = data.index.tolist(), title='Target Classes')
fig.update_yaxes(tickformat=',', title='count')
fig.update_xaxes(title='classes')
fig.update_layout(width=800, height=700)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="559bb247-54b8-4dfc-9608-5c7abf7a4371" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("559bb247-54b8-4dfc-9608-5c7abf7a4371")) {                    Plotly.newPlot(                        "559bb247-54b8-4dfc-9608-5c7abf7a4371",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["negative","neutral","positive","somehow negative","somehow positive"],"xaxis":"x","y":[7057,77773,9193,27141,32767],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# ### 타겟 클래스 간 비율 확인

# %%
sentiment_counts = train['sentiment_class'].value_counts().reset_index()
sentiment_counts.columns = ['sentiment_class', 'count']
sentiment_counts['percentage'] = (sentiment_counts['count'] / train.shape[0]) * 100

pie_chart = px.pie(sentiment_counts, names='sentiment_class', values='percentage', title='% Target class', labels={'percentage':'% of Total'})
pie_chart.update_traces(textinfo='percent+label')
pie_chart.update_layout(width=800, height=700)
pie_chart.show()
# Out:
# <div>                            <div id="678bab4f-1abb-41cd-83e3-910e08373ca9" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("678bab4f-1abb-41cd-83e3-910e08373ca9")) {                    Plotly.newPlot(                        "678bab4f-1abb-41cd-83e3-910e08373ca9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"sentiment_class=%{label}\u003cbr\u003e% of Total=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["neutral","somehow positive","somehow negative","positive","negative"],"legendgroup":"","name":"","showlegend":true,"values":[50.52458569099142,21.286810324106256,17.631925992814963,5.972156355769793,4.584521636317571],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outl ...

# %% [markdown]
# ### 문장 길이 컬럼 추가

# %%
train['PhraseLength'] = train['Phrase'].apply(lambda x : len(x))
train.sort_values(by="PhraseLength", ascending=False).head()
# Out:
#         PhraseId  SentenceId  \
# 149938    149939        8167
# 149939    149940        8167
# 149940    149941        8167
# 149941    149942        8167
# 54876      54877        2734
#
#                                                    Phrase  Sentiment  \
# 149938  hard imagine anyone managing steal movie only ...          4
# 149939  hard imagine anyone managing steal movie only ...          4
# 149940  hard imagine anyone managing steal movie only ...          3
# 149941  hard imagine anyone managing steal movie only ...          4
# 54876   Filmmakers Dana JanklowiczMann Amir Mann area ...          3
#
#          sentiment_class  PhraseLength
# 149938          positive           215
# 149939          positive           215
# 149940  somehow positive           215
# 149941          positive           215
# 54876   somehow positive           213

# %% [markdown]
# ### 각 클래스에 대한 문장의 길이 시각화

# %%
import plotly.graph_objects as go

negative_legnth = train[train['sentiment_class'] == 'negative']['PhraseLength']
somehow_negative_legnth = train[train['sentiment_class'] == 'somehow negative']['PhraseLength']
neutral_legnth = train[train['sentiment_class'] == 'neutral']['PhraseLength']
somehow_positive_legnth = train[train['sentiment_class'] == 'somehow positive']['PhraseLength']
positive_legnth = train[train['sentiment_class'] == 'positive']['PhraseLength']

length_dist = go.Figure()
length_dist.add_trace(go.Histogram(x=negative_legnth, histnorm = 'probability'))
length_dist.add_trace(go.Histogram(x=somehow_negative_legnth, histnorm = 'probability'))
length_dist.add_trace(go.Histogram(x=neutral_legnth, histnorm = 'probability'))
length_dist.add_trace(go.Histogram(x=somehow_positive_legnth, histnorm = 'probability'))
length_dist.add_trace(go.Histogram(x=positive_legnth, histnorm = 'probability'))
length_dist.update_layout(width=1200, height=700)
length_dist.show()
# Out:
# <div>                            <div id="15162bab-642c-4226-928c-7ce004ef514d" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15162bab-642c-4226-928c-7ce004ef514d")) {                    Plotly.newPlot(                        "15162bab-642c-4226-928c-7ce004ef514d",                        [{"histnorm":"probability","x":[41,35,51,40,27,13,13,22,4,4,113,32,82,20,39,5,67,83,43,39,18,18,99,18,44,14,23,99,32,27,22,17,76,63,10,10,21,92,61,140,118,118,53,15,30,10,101,15,70,10,89,35,113,93,22,14,70,49,42,42,100,100,87,87,87,87,29,23,57,47,5,22,78,78,119,119,120,102,4,81,32,85,131,120,103,103,103,103,94,94,87,87,48,33,27,30,5,26,6,24,21,21,81,32,69,44,23,23,10,26,18,18,147,147,108,16,10,10,38,34,34,22,10,8,80,110,9,4,86,70,40,40,35,30,30,19,88,64,64,48,26,42,46,35,35,12,89,30,30,23,9,12,60,82,25,7,21,25,78,37,10,8,40,70,57,105,105,105,105,18,18,42,20,78,19,85,79,74,68,29,38,27,103,96,78,54,49,49,49,31,112,112,112,102,89,44,35,38,38,17,67,51,29,29,24,18,57,37,19,37,21,81,76,57,25,138,96,96,96,96,75,53,37,19,11,51,51,30,40,28,10,80,37,18,13,42,20,11,103,57,57,36,36,27,8,72,20,20,15,51,51,51,30,13,6,33,15,9,30,28,46,12,12,64,64,59,161,12,35,66,59,49,44,39,32,25,33,32,32,10,21,7,122,97,20,15,89,89,89,81,81,71,8,105,71,54,43,38,38,33,9,16,16,7,142,78,36,36,7,7,20,8,41,18,9,67,34,15,46,44,28,9,9,14,4,70,61,15,55,33,33,6,6,26,16,6,6,21,21,112,95,95,50,87,42,81,8,85,30,54,54,27,27,19,60,88,29,5,65,47,47,27,6,34,53,35,28,72,41,19,19,111,39,34,26,48,70,32,29,48,145,70,45,86,38,27,22,21,6,60,6,9,9,36,36,36,96,34,107,97,19,25,25,25,20,75,75,22,47,8,116,82,63,29,33,33,33,10,18,35,35,133,133,93,93,27,104,33,33,28,108,24,24,31,13,39,106,106,106,106,101,95,95,11,11,77,77,91,44,31,12,12,124,39,24,19,10,10,16,5,5,5,20,74,63,63,12,159,84,78,71,20,8,6,102,88,88,88,57,52,34,7,26,11,27,13,25,25,17,12,21,9,17,17,118,103,14,9,28,11,60,51,54,95,83,83,37,45,40,99,32,26,26,10,5,78,23,83,83,46,46,40,28,71,71,25,25,34,43,23,11,61,44,11,82,99,99,93,93,93,26,20,15,15,44,106,70,70,49,49,49,27,27,27,27,14,21,62,62,62,22,56,33,23,11,11,11,11,27,21,47,6,14,42,70,70,70,40,31,5,76,63,107,41,117,90,73,73,34,43,20,49,30,30,6,101,54,18,80,80,80,80,74,64,64,59,59,54,54,20,20,33,67,67,67,32,23,21,113,75,32,13,82,65,20,61,10,37,26,49,23,37,37,84,17,12,12,12,7,34,86,9,9,46,40,12,12,94,21,11,85,85,43,80,62,56,24,24,24,11,11,12,137,137,99,99,99,21,58,46,33,18,52,41,11,11,17,35,24,36,125,56,55,55,55,36,10,4,41,24,18,18,20,20,25,25,17,17,8,57,36,80,60,42,42,34,34,29,29,17,89,73,53,16,84,35,76,43,33,113,104,35,19,45,24,53,99,68,58,58,19,19,38,6,10,5,54,26,37,54,23,23,5,59,52,33,4,58,20,76,79,71,71,62,29,24,15,61,61,61,38,38,38,29,19,14,9,6,24,92,44,145,53,28,15,4,43,43,43,38,33,41,35,35,126,60,28,28,57,42,23,23,12,27,51,11,46,28,115,99,23,7,95,26,26,38,40,40,27,27,13,21,27,11,6,82,69,28,23,12,123,24,13,74,69,64,42,37,30,4,17,17,11,56,40,44,47,41,41,58,52,52,46,46,10,10,71,71,69,17,90,84,82,77,77,72,51,51,10,129,47,42,31,14,16,81,81,42,24,42,42,21,133,116,105,105,89,76,51,46,46,21,77,43,14,14,18,10,10,10,10,14,14,45,45,32,107,76,48,71,35,35,30,78,25,20,42,42,13,30,30,11,16,29,24,59,105,105,95,95,42,42,12,96,96,81,70,22,56,66,48,32,16,72,72,72,72,56,129,106,58,145,139,139,60,11,73,54,47,19,131,17,122,6,15,27,21,42,17,69,34,22,76,40,40,18,12,12,51,94,85,33,51,43,144,137,129,83,78,78,6,66,48,33,85,74,59,51,34,34,20,41,41,31,24,28,39,39,79,73,73,73,44,44,44,92,78,31,78,43,43,43,40,40,40,35,25,25,31,91,43,19,34,6,47,47,76,70,70,70,106,93,59,35,40,31,100,23,127,113,82,82,16,31,22,9,72,27,82,7,6,105,82,43,43,43,6,18,12,32,22,14,30,25,166,125,58,39,65,81,89,89,89,10,5,5,5,5,42,31,57,57,13,23,18,5,97,6,40,34,92,73,73,66,49,35,63,16,34,34,34,34,32,21,21,21,11,18,34,83,83,73,36,40,34,7,15,87,11,38,38,84,84,50,17,98,98,76,76,17,53,79,32,32,10,85,50,50,38,33,2 ...

# %% [markdown]
# ### WordCloud를 활용하여 자주 나오는 단어 시각화

# %%
from wordcloud import WordCloud, STOPWORDS
stopword_ = set(STOPWORDS)

word_cloud_common_words = []
for _, row in train.iterrows():
    word_cloud_common_words.append(row['Phrase'])
word_cloud_common_words
# Out:
# ['series escapades demonstrating adage that what good goose also good gander some which occasionally amuses none which amounts much story',
#  'series escapades demonstrating adage that what good goose',
#  'series',
#  'series',
#  'escapades demonstrating adage that what good goose',
#  'escapades demonstrating adage that what good goose',
#  'escapades',
#  'demonstrating adage that what good goose',
#  'demonstrating adage',
#  'demonstrating',
#  'adage',
#  'adage',
#  'that what good goose',
#  'that',
#  'what good goose',
#  'what',
#  'good goose',
#  'good goose',
#  'good',
#  'goose',
#  'goose',
#  'goose',
#  'also good gander some which occasionally amuses none which amounts much story',
#  'also good gander some which occasionally amuses none which amounts much story',
#  'also',
#  'also',
#  'good gander some which occasionally amuses none which amounts much story',
#  'gander some which occasionally amuses none which amounts much story',
#  'gander some which occasionally amuses none which amounts much story',
#  'gander',
#  'gander',
#  'gander',
#  'some which occasionally amuses none which amounts much story',
#  'some which',
#  'some',
#  'which',
#  'which',
#  'occasionally amuses none which amounts much story',
#  'occasionally',
#  'amuses none which amounts much story',
#  'amuses',
#  'none which amounts much story',
#  'none which amounts much story',
#  'none',
#  'which amounts much story',
#  'which amounts much story',
#  'amounts much story',
#  'amounts',
#  'much story',
#  'much story',
#  'much',
#  'story',
#  'story',
#  'story',
#  'This quiet introspective entertaining independent worth seeking',
#  'This quiet introspective entertaining independent',
#  'This',
#  'quiet introspective entertaining independent',
#  'quiet introspective entertaining',
#  'quiet',
#  'introspective entertaining',
#  'introspective entertaining',
#  'introspective',
#  'introspective',
#  'entertaining',
#  'independent',
#  'worth seeking',
#  'worth seeking',
#  'worth',
#  'worth',
#  'seeking',
#  'Even fans Ismail Merchant work suspect would have hard time sitting through this',
#  'Even fans Ismail Merchant work',
#  'Even fans',
#  'Even',
#  'fans',
#  'Ismail Merchant work',
#  'Ismail Merchant work',
#  'Ismail Merchant',
#  'Ismail',
#  'Merchant',
#  'Merchant',
#  'work',
#  'suspect would have hard time sitting through this',
#  'suspect',
#  'suspect',
#  'suspect',
#  'suspect',
#  'would have hard time sitting through this',
#  'would have hard time sitting through this',
#  'would',
#  'have hard time sitting through this',
#  'have',
#  'hard time sitting through this',
#  'hard time',
#  'hard time',
#  'hard',
#  'time',
#  'sitting through this',
#  'sitting',
#  'through this',
#  'through',
#  'this',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder Shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder Shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder',
#  'positively thrilling combination',
#  'positively thrilling combination',
#  'positively',
#  'thrilling combination',
#  'thrilling',
#  'combination',
#  'ethnography intrigue betrayal deceit murder',
#  'ethnography intrigue betrayal deceit murder',
#  'ethnography',
#  'ethnography',
#  'intrigue betrayal deceit murder',
#  'intrigue betrayal deceit murder',
#  'intrigue betrayal deceit murder',
#  'intrigue',
#  'betrayal deceit murder',
#  'betrayal deceit murder',
#  'betrayal',
#  'deceit murder',
#  'deceit murder',
#  'deceit',
#  'deceit',
#  'murder',
#  'Shakespearean tragedy juicy soap opera',
#  'Shakespearean tragedy juicy soap opera',
#  'Shakespearean tragedy',
#  'Shakespearean tragedy',
#  'Shakespearean tragedy',
#  'Shakespearean',
#  'tragedy',
#  'juicy soap opera',
#  'juicy soap opera',
#  'juicy',
#  'soap opera',
#  'soap',
#  'opera',
#  'Aggressive selfglorification manipulative whitewash',
#  'Aggressive selfglorification manipulative whitewash',
#  'Aggressive',
#  'selfglorification manipulative whitewash',
#  'selfglorification',
#  'selfglorification',
#  'manipulative whitewash',
#  'manipulative whitewash',
#  'manipulative',
#  'whitewash',
#  'comedydrama nearly epic proportions rooted sincere performance title character undergoing midlife crisis',
#  'comedydrama nearly epic proportions',
#  'comedydrama',
#  'comedydrama',
#  'nearly epic proportions',
#  'nearly epic proportions',
#  'nearly epic',
#  'nearly',
#  'epic',
#  'proportions',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'rooted sincere performance',
#  'rooted',
#  'sincere performance',
#  'sincere performance',
#  'sincere performance',
#  'sincere',
#  'performance',
#  'title character undergoing midlife crisis',
#  'title character undergoing midlife crisis',
#  'title character',
#  'title character',
#  'title',
#  'character',
#  'undergoing midlife crisis',
#  'undergoing',
#  'midlife crisis',
#  'midlife',
#  'crisis',
#  'Narratively Trouble Every plodding mess',
#  'Narratively',
#  'Trouble Every plodding mess',
#  'Trouble Every plodding mess',
#  'Trouble Every',
#  'Trouble',
#  'Every',
#  'Every',
#  'plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'plodding',
#  'mess',
#  'Importance Being Earnest thick with plays like reading from Bartlett Familiar Quotations',
#  'Importance',
#  'Importance',
#  'Being Earnest thick with plays like reading from Bartlett Familiar Quotations',
#  'Being Earnest thick with plays like reading from Bartlett Familiar Quotations',
#  'Being',
#  'Earnest thick with plays like reading from Bartlett Familiar Quotations',
#  'Earnest',
#  'Earnest',
#  'thick with plays like reading from Bartlett Familiar Quotations',
#  'thick with plays like reading from Bartlett Familiar Quotations',
#  'thick',
#  'with plays like reading from Bartlett Familiar Quotations',
#  'with',
#  'plays like reading from Bartlett Familiar Quotations',
#  'plays like reading from Bartlett Familiar Quotations',
#  'plays like reading from Bartlett Familiar Quotations',
#  'plays',
#  'like reading from Bartlett Familiar Quotations',
#  'like',
#  'reading from Bartlett Familiar Quotations',
#  'reading',
#  'reading',
#  'from Bartlett Familiar Quotations',
#  'from',
#  'Bartlett Familiar Quotations',
#  'Bartlett',
#  'Bartlett',
#  'Familiar Quotations',
#  'Familiar',
#  'Quotations',
#  'does leave with much',
#  'does leave with much',
#  'does leave with much',
#  'does leave with much',
#  'does',
#  'does',
#  'leave with much',
#  'leave',
#  'leave',
#  'with much',
#  'could hate same reason',
#  'could hate same reason',
#  'could hate same reason',
#  'could',
#  'hate same reason',
#  'hate',
#  'hate',
#  'same reason',
#  'same reason',
#  'same reason',
#  'same',
#  'reason',
#  'There little recommend Snow Dogs unless considers cliched dialogue perverse escapism source high hilarity',
#  'There',
#  'little recommend Snow Dogs unless considers cliched dialogue perverse escapism source high hilarity',
#  'little recommend Snow Dogs unless considers cliched dialogue perverse escapism source high hilarity',
#  'little recommend Snow Dogs',
#  'little recommend Snow Dogs',
#  'little recommend Snow Dogs',
#  'little',
#  'recommend Snow Dogs',
#  'recommend Snow Dogs',
#  'recommend',
#  'Snow Dogs',
#  'Snow',
#  'Dogs',
#  'unless considers cliched dialogue perverse escapism source high hilarity',
#  'unless',
#  'considers cliched dialogue perverse escapism source high hilarity',
#  'considers cliched dialogue perverse escapism source high hilarity',
#  'considers',
#  'cliched dialogue perverse escapism source high hilarity',
#  'cliched dialogue perverse escapism',
#  'cliched dialogue',
#  'cliched dialogue',
#  'cliched',
#  'dialogue',
#  'perverse escapism',
#  'perverse',
#  'escapism',
#  'source high hilarity',
#  'source',
#  'source',
#  'high hilarity',
#  'high hilarity',
#  'high',
#  'hilarity',
#  'Kung Oedekerk realization childhood dream martialarts flick proves that sometimes dreams youth should remain just that',
#  'Kung',
#  'Kung',
#  'Oedekerk realization childhood dream martialarts flick proves that sometimes dreams youth should remain just that',
#  'Oedekerk realization childhood dream martialarts flick proves that sometimes dreams youth should remain just that',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream martialarts flick',
#  'Oedekerk realization childhood dream',
#  'Oedekerk realization',
#  'Oedekerk',
#  'Oedekerk',
#  'realization',
#  'childhood dream',
#  'childhood dream',
#  'childhood dream',
#  'childhood',
#  'dream',
#  'martialarts flick',
#  'martialarts flick',
#  'martialarts flick',
#  'martialarts flick',
#  'martialarts flick',
#  'martialarts',
#  'flick',
#  'proves that sometimes dreams youth should remain just that',
#  'proves',
#  'that sometimes dreams youth should remain just that',
#  'sometimes dreams youth should remain just that',
#  'sometimes',
#  'dreams youth should remain just that',
#  'dreams youth',
#  'dreams',
#  'dreams',
#  'youth',
#  'youth',
#  'should remain just that',
#  'should',
#  'remain just that',
#  'remain',
#  'just that',
#  'just',
#  'performances absolute',
#  'performances',
#  'performances',
#  'absolute',
#  'absolute',
#  'absolute',
#  'absolute',
#  'absolute',
#  'Fresnadillo something serious about ways which extravagant chance distort perspective throw path good sense',
#  'Fresnadillo',
#  'something serious about ways which extravagant chance distort perspective throw path good sense',
#  'something serious about ways which extravagant chance distort perspective throw path good sense',
#  'something serious about ways which extravagant chance distort perspective throw path good sense',
#  'something',
#  'serious about ways which extravagant chance distort perspective throw path good sense',
#  'serious',
#  'about ways which extravagant chance distort perspective throw path good sense',
#  'about ways which extravagant chance distort perspective throw path good sense',
#  'about ways which extravagant chance distort perspective throw path good sense',
#  'about',
#  'ways which extravagant chance distort perspective throw path good sense',
#  'ways',
#  'ways',
#  'which extravagant chance distort perspective throw path good sense',
#  'which',
#  'extravagant chance distort perspective throw path good sense',
#  'extravagant chance',
#  'extravagant',
#  'chance',
#  'distort perspective throw path good sense',
#  'distort perspective throw path good sense',
#  'distort perspective',
#  'distort perspective',
#  'distort',
#  'perspective',
#  'perspective',
#  'throw path good sense',
#  'throw',
#  'throw',
#  'path good sense',
#  'path good sense',
#  'path',
#  'path',
#  'good sense',
#  'good sense',
#  'sense',
#  'still like Moonlight Mile better judgment damned',
#  'still like Moonlight Mile better judgment damned',
#  'still',
#  'like Moonlight Mile better judgment damned',
#  'like Moonlight Mile better judgment damned',
#  'Moonlight Mile better judgment damned',
#  'Moonlight Mile better judgment',
#  'Moonlight',
#  'Mile better judgment',
#  'Mile',
#  'better judgment',
#  'better judgment',
#  'better',
#  'judgment',
#  'damned',
#  'damned',
#  'welcome relief from baseball movies that hard mythic this sweet modest ultimately winning story',
#  'welcome relief from baseball movies that hard mythic',
#  'welcome relief',
#  'welcome relief',
#  'welcome',
#  'relief',
#  'from baseball movies that hard mythic',
#  'baseball movies that hard mythic',
#  'baseball movies',
#  'baseball',
#  'movies',
#  'that hard mythic',
#  'hard mythic',
#  'hard mythic',
#  'hard mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'this sweet modest ultimately winning story',
#  'this sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest',
#  'sweet modest',
#  'sweet modest',
#  'sweet',
#  'sweet',
#  'modest',
#  'ultimately winning story',
#  'ultimately',
#  'winning story',
#  'winning',
#  'bilingual charmer just like woman inspired',
#  'bilingual charmer',
#  'bilingual charmer',
#  'bilingual charmer',
#  'bilingual',
#  'charmer',
#  'just like woman inspired',
#  'like woman inspired',
#  'woman inspired',
#  'woman',
#  'woman',
#  'inspired',
#  'inspired',
#  'inspired',
#  'Like less dizzily gorgeous companion Wong Mood Love very much Hong Kong movie despite mainland setting',
#  'Like less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous companion',
#  'less dizzily gorgeous',
#  'less',
#  'dizzily gorgeous',
#  'dizzily',
#  'gorgeous',
#  'companion',
#  'Wong Mood Love very much Hong Kong movie despite mainland setting',
#  'Wong',
#  'Mood Love very much Hong Kong movie despite mainland setting',
#  'Mood Love very much Hong Kong movie despite mainland setting',
#  'Mood Love very much Hong Kong movie',
#  'Mood Love very much Hong Kong movie',
#  'Mood Love very much Hong Kong movie',
#  'Mood',
#  'Mood',
#  'Love very much Hong Kong movie',
#  'Love very much Hong Kong movie',
#  'Love very much',
#  'Love',
#  'Love',
#  'very much',
#  'very',
#  'Hong Kong movie',
#  'Hong Kong movie',
#  'Hong',
#  'Kong movie',
#  'Kong',
#  'movie',
#  'despite mainland setting',
#  'despite',
#  'mainland setting',
#  'mainland setting',
#  'mainland',
#  'setting',
#  'inept bigscreen remakes Avengers Wild Wild West',
#  'inept bigscreen remakes Avengers Wild Wild West',
#  'inept',
#  'inept',
#  'bigscreen remakes Avengers Wild Wild West',
#  'bigscreen remakes Avengers Wild Wild West',
#  'bigscreen remakes',
#  'bigscreen',
#  'remakes',
#  'Avengers Wild Wild West',
#  'Avengers Wild Wild West',
#  'Avengers',
#  'Avengers',
#  'Avengers',
#  'Wild Wild West',
#  'Wild Wild West',
#  'Wild',
#  'Wild West',
#  'West',
#  'everything expect nothing more',
#  'everything expect nothing more',
#  'everything expect nothing more',
#  'everything expect nothing more',
#  'everything',
#  'expect nothing more',
#  'expect nothing more',
#  'expect nothing more',
#  'expect nothing',
#  'expect',
#  'expect',
#  'nothing',
#  'nothing',
#  'more',
#  'Best indie year',
#  'Best',
#  'indie year',
#  'indie year',
#  'indie year',
#  'indie year',
#  'indie',
#  'year',
#  'year',
#  'year',
#  'Hatfield Hicks make oddest couples this sense movie becomes study gambles publishing world offering case study that exists apart from movie political ramifications',
#  'Hatfield Hicks make oddest couples this sense movie becomes study gambles publishing world offering case study that exists apart from movie political ramifications',
#  'Hatfield Hicks make oddest couples',
#  'Hatfield Hicks make oddest couples',
#  'Hatfield Hicks make oddest couples',
#  'Hatfield Hicks',
#  'Hatfield',
#  'Hatfield',
#  'Hicks',
#  'make oddest couples',
#  'make',
#  'oddest couples',
#  'oddest',
#  'oddest',
#  'couples',
#  'couples',
#  'this sense movie becomes study gambles publishing world offering case study that exists apart from movie political ramifications',
#  'this sense',
#  'this sense',
#  'movie becomes study gambles publishing world offering case study that exists apart from movie political ramifications',
#  'movie',
#  'becomes study gambles publishing world offering case study that exists apart from movie political ramifications',
#  'becomes study gambles publishing world',
#  'becomes study gambles publishing world',
#  'becomes',
#  'study gambles publishing world',
#  'study',
#  'study',
#  'gambles publishing world',
#  'gambles publishing world',
#  'gambles',
#  'gambles',
#  'publishing world',
#  'publishing world',
#  'publishing world',
#  'publishing',
#  'world',
#  'offering case study that exists apart from movie political ramifications',
#  'offering',
#  'case study that exists apart from movie political ramifications',
#  'case study',
#  'case study',
#  'case',
#  'that exists apart from movie political ramifications',
#  'exists apart from movie political ramifications',
#  'exists apart',
#  'exists',
#  'apart',
#  'from movie political ramifications',
#  'movie political ramifications',
#  'movie political ramifications',
#  'movie',
#  'movie',
#  'political ramifications',
#  'political',
#  'ramifications',
#  'like going house party watching host defend himself against frothing exgirlfriend',
#  'like going house party watching host defend himself against frothing exgirlfriend',
#  'like going house party watching host defend himself against frothing exgirlfriend',
#  'like going house party watching host defend himself against frothing exgirlfriend',
#  'going house party watching host defend himself against frothing exgirlfriend',
#  'going house party',
#  'going house party',
#  'going',
#  'house party',
#  'house party',
#  'house party',
#  'house',
#  'party',
#  'watching host defend himself against frothing exgirlfriend',
#  'watching',
#  'host defend himself against frothing exgirlfriend',
#  'host',
#  'host',
#  'defend himself against frothing exgirlfriend',
#  'defend himself',
#  'defend',
#  'himself',
#  'against frothing exgirlfriend',
#  'against',
#  'frothing exgirlfriend',
#  'frothing exgirlfriend',
#  'frothing',
#  'exgirlfriend',
#  'That Chuck Norris grenade occurs about times during Windtalkers good indication seriousminded film',
#  'That Chuck Norris grenade',
#  'Chuck Norris grenade',
#  'Chuck Norris grenade',
#  'Chuck',
#  'Norris grenade',
#  'Norris',
#  'grenade',
#  'grenade',
#  'grenade',
#  'occurs about times during Windtalkers good indication seriousminded film',
#  'occurs about times during Windtalkers good indication seriousminded film',
#  'occurs',
#  'about times during Windtalkers good indication seriousminded film',
#  'about times during Windtalkers',
#  'about times',
#  'times',
#  'times',
#  'during Windtalkers',
#  'during',
#  'Windtalkers',
#  'good indication seriousminded film',
#  'good indication seriousminded film',
#  'good indication',
#  'good indication',
#  'indication',
#  'seriousminded film',
#  'seriousminded film',
#  'seriousminded film',
#  'seriousminded film',
#  'seriousminded',
#  'film',
#  'film',
#  'plot romantic comedy boilerplate from start finish',
#  'plot',
#  'plot',
#  'romantic comedy boilerplate from start finish',
#  'romantic comedy boilerplate from start finish',
#  'romantic comedy boilerplate from start finish',
#  'romantic comedy boilerplate from start',
#  'romantic comedy boilerplate',
#  'romantic',
#  'comedy boilerplate',
#  'comedy',
#  'boilerplate',
#  'from start',
#  'start',
#  'finish',
#  'finish',
#  'arrives with impeccable pedigree mongrel almost indecipherable plot complications',
#  'arrives with impeccable pedigree mongrel almost indecipherable plot complications',
#  'arrives with impeccable pedigree mongrel almost indecipherable plot complications',
#  'arrives',
#  'with impeccable pedigree mongrel almost indecipherable plot complications',
#  'impeccable pedigree mongrel almost indecipherable plot complications',
#  'impeccable pedigree mongrel almost',
#  'impeccable pedigree mongrel',
#  'impeccable pedigree mongrel',
#  'impeccable pedigree mongrel',
#  'impeccable pedigree mongrel',
#  'impeccable',
#  'pedigree mongrel',
#  'pedigree',
#  'mongrel',
#  'mongrel',
#  'mongrel',
#  'almost',
#  'indecipherable plot complications',
#  'indecipherable',
#  'plot complications',
#  'complications',
#  'film that clearly means preach exclusively converted',
#  'film that clearly means',
#  'film',
#  'that clearly means',
#  'clearly means',
#  'clearly',
#  'means',
#  'means',
#  'preach exclusively converted',
#  'preach exclusively converted',
#  'preach exclusively',
#  'preach',
#  'exclusively',
#  'converted',
#  'converted',
#  'converted',
#  'While Importance Being Earnest offers opportunities occasional smiles chuckles does give reason theater beyond Wilde actors performances',
#  'While Importance Being Earnest offers opportunities occasional smiles chuckles',
#  'While',
#  'Importance Being Earnest offers opportunities occasional smiles chuckles',
#  'Importance Being Earnest',
#  'Being Earnest',
#  'Being Earnest',
#  'offers opportunities occasional smiles chuckles',
#  'offers opportunities occasional smiles',
#  'offers opportunities occasional smiles',
#  'offers',
#  'opportunities occasional smiles',
#  'opportunities',
#  'occasional smiles',
#  'occasional smiles',
#  'occasional',
#  'smiles',
#  'chuckles',
#  'does give reason theater beyond Wilde actors performances',
#  'does give reason theater beyond Wilde actors performances',
#  'does give reason theater beyond Wilde actors performances',
#  'does give reason theater beyond Wilde actors performances',
#  'give reason theater beyond Wilde actors performances',
#  'give',
#  'give',
#  'reason theater beyond Wilde actors performances',
#  'reason theater beyond Wilde actors performances',
#  'theater beyond Wilde actors performances',
#  'theater beyond Wilde actors performances',
#  'theater',
#  'theater',
#  'theater',
#  'theater',
#  'beyond Wilde actors performances',
#  'beyond',
#  'Wilde actors performances',
#  'Wilde',
#  'Wilde',
#  'Wilde',
#  'Wilde',
#  'actors performances',
#  'actors',
#  'actors',
#  'actors',
#  'latest vapid actor exercise appropriate structure Arthur Schnitzler Reigen',
#  'latest',
#  'latest',
#  'vapid actor exercise appropriate structure Arthur Schnitzler Reigen',
#  'vapid actor exercise appropriate structure Arthur Schnitzler Reigen',
#  'vapid actor exercise',
#  'vapid',
#  'actor exercise',
#  'actor',
#  'actor',
#  'exercise',
#  'appropriate structure Arthur Schnitzler Reigen',
#  'appropriate structure Arthur Schnitzler Reigen',
#  'appropriate structure',
#  'appropriate',
#  'structure',
#  'structure',
#  'Arthur Schnitzler Reigen',
#  'Arthur Schnitzler Reigen',
#  'Arthur Schnitzler',
#  'Arthur',
#  'Schnitzler',
#  'Schnitzler',
#  'Reigen',
#  'More vaudeville show than wellconstructed narrative those terms inoffensive actually rather sweet',
#  'More vaudeville show than wellconstructed narrative those terms inoffensive actually rather sweet',
#  'More vaudeville show than wellconstructed narrative',
#  'More vaudeville show than wellconstructed narrative',
#  'More vaudeville show than wellconstructed narrative',
#  'More vaudeville',
#  'vaudeville',
#  'show than wellconstructed narrative',
#  'show',
#  'than wellconstructed narrative',
#  'than',
#  'wellconstructed narrative',
#  'wellconstructed',
#  'narrative',
#  'those terms inoffensive actually rather sweet',
#  'those terms',
#  'those terms',
#  'those',
#  'terms',
#  'inoffensive actually rather sweet',
#  'inoffensive actually rather sweet',
#  'inoffensive actually rather sweet',
#  'inoffensive actually',
#  'inoffensive',
#  'inoffensive',
#  'actually',
#  'rather sweet',
#  'rather',
#  'Nothing more than runofthemill action flick',
#  'more than runofthemill action flick',
#  'more than runofthemill action',
#  'than runofthemill action',
#  'runofthemill action',
#  'runofthemill action',
#  'runofthemill',
#  'action',
#  'flick',
#  'Hampered paralyzed selfindulgent script that aims poetry ends sounding like satire',
#  'Hampered paralyzed selfindulgent script that aims poetry ends sounding like satire',
#  'Hampered paralyzed selfindulgent script',
#  'Hampered paralyzed selfindulgent script',
#  'Hampered paralyzed',
#  'Hampered',
#  'paralyzed',
#  'paralyzed',
#  'paralyzed',
#  'paralyzed',
#  'paralyzed',
#  'selfindulgent script',
#  'selfindulgent script',
#  'selfindulgent script',
#  'selfindulgent',
#  'script',
#  'that aims poetry ends sounding like satire',
#  'aims poetry ends sounding like satire',
#  'aims poetry',
#  'aims poetry',
#  'aims',
#  'poetry',
#  'poetry',
#  'ends sounding like satire',
#  'ends',
#  'ends',
#  'sounding like satire',
#  'sounding',
#  'like satire',
#  'satire',
#  'first computergenerated feature cartoon feel like other movies that makes some glacial pacing early',
#  'first computergenerated feature cartoon feel like other movies that makes some glacial pacing early',
#  'first computergenerated feature cartoon feel like other movies',
#  'first computergenerated feature cartoon feel like other movies',
#  'first computergenerated feature cartoon feel like other movies',
#  'first computergenerated feature cartoon feel like other movies',
#  'first computergenerated feature cartoon feel like other movies',
#  'first computergenerated feature cartoon',
#  'first computergenerated feature cartoon',
#  'first',
#  'computergenerated feature cartoon',
#  'computergenerated',
#  'feature cartoon',
#  'feature',
#  'cartoon',
#  'feel like other movies',
#  'feel like other movies',
#  'feel',
#  'like other movies',
#  'other movies',
#  'other',
#  'that makes some glacial pacing early',
#  'makes some glacial pacing early',
#  'makes some glacial pacing',
#  'makes',
#  'some glacial pacing',
#  'some glacial pacing',
#  'glacial pacing',
#  'glacial',
#  'pacing',
#  'early',
#  'early',
#  'There very little sense what going here makers serve cliches with considerable dash',
#  'There very little sense what going here makers serve cliches with considerable dash',
#  'There very little sense what going here',
#  'There very little sense what going here',
#  'There very little sense what going here',
#  'very little sense what going here',
#  'very little sense what going here',
#  'very little sense',
#  'very little',
#  'what going here',
#  'what going here',
#  'going here',
#  'going here',
#  'going',
#  'here',
#  'makers serve cliches with considerable dash',
#  'makers',
#  'makers',
#  'serve cliches with considerable dash',
#  'serve',
#  'serve',
#  'cliches with considerable dash',
#  'cliches',
#  'cliches',
#  'with considerable dash',
#  'considerable dash',
#  'considerable',
#  'dash',
#  'Cattaneo should have followed runaway success first film Full Monty with something different',
#  'Cattaneo',
#  'should have followed runaway success first film Full Monty with something different',
#  'should have followed runaway success first film Full Monty with something different',
#  'have followed runaway success first film Full Monty with something different',
#  'followed runaway success first film Full Monty with something different',
#  'followed runaway success first film Full Monty',
#  'followed',
#  'runaway success first film Full Monty',
#  'runaway success',
#  'runaway success',
#  'runaway',
#  'success',
#  'first film Full Monty',
#  'first film Full Monty',
#  'first film Full Monty',
#  'first film',
#  'first film',
#  'first film',
#  'Full Monty',
#  'Full Monty',
#  'Full',
#  'Monty',
#  'with something different',
#  'something different',
#  'different',
#  'They unnamed easily substitutable forces that serve whatever terror heroes horror movies avoid',
#  'They',
#  'unnamed easily substitutable forces that serve whatever terror heroes horror movies avoid',
#  'unnamed easily substitutable forces that serve whatever terror heroes horror movies avoid',
#  'unnamed easily substitutable forces that serve whatever terror heroes horror movies avoid',
#  'unnamed easily substitutable forces',
#  'unnamed easily substitutable forces',
#  'unnamed easily substitutable',
#  'unnamed',
#  'easily substitutable',
#  'easily substitutable',
#  'easily',
#  'substitutable',
#  'forces',
#  'that serve whatever terror heroes horror movies avoid',
#  'serve whatever terror heroes horror movies avoid',
#  'whatever terror heroes horror movies avoid',
#  'whatever terror heroes horror movies avoid',
#  'whatever',
#  'terror heroes horror movies avoid',
#  'terror',
#  'heroes horror movies avoid',
#  'heroes horror movies',
#  'heroes',
#  'heroes',
#  'horror movies',
#  'horror movies',
#  'horror',
#  'avoid',
#  'avoid',
#  'avoid',
#  'almost feels movie more interested entertaining itself than amusing',
#  'almost feels movie more interested entertaining itself than amusing',
#  'feels movie more interested entertaining itself than amusing',
#  'feels movie more interested entertaining itself than amusing',
#  'feels',
#  'movie more interested entertaining itself than amusing',
#  'movie more interested entertaining itself than amusing',
#  'movie more interested entertaining itself than amusing',
#  'more interested entertaining itself than amusing',
#  'more interested entertaining itself than amusing',
#  'more interested entertaining itself',
#  'interested entertaining itself',
#  'interested',
#  'entertaining itself',
#  'entertaining itself',
#  'itself',
#  'than amusing',
#  'amusing',
#  'amusing',
#  'amusing',
#  'movie progression into rambling incoherence gives meaning phrase fatal script error',
#  'movie progression into rambling incoherence',
#  'movie progression',
#  'progression',
#  'into rambling incoherence',
#  'into',
#  'rambling incoherence',
#  'rambling',
#  'incoherence',
#  'gives meaning phrase fatal script error',
#  'gives meaning phrase fatal script error',
#  'gives meaning phrase fatal script error',
#  'gives meaning',
#  'gives',
#  'meaning',
#  'meaning',
#  'phrase fatal script error',
#  'phrase fatal script error',
#  'phrase fatal script error',
#  'phrase',
#  'fatal script error',
#  'fatal script error',
#  'fatal',
#  'script error',
#  'error',
#  'judge this soon dark gritty story takes totally unexpected directions keeps going',
#  'judge this soon dark gritty story takes totally unexpected directions keeps going',
#  'judge this soon',
#  'judge this soon',
#  'judge this soon',
#  'judge this',
#  'judge',
#  'soon',
#  'soon',
#  'dark gritty story takes totally unexpected directions keeps going',
#  'dark gritty story',
#  'dark gritty story',
#  'dark gritty story',
#  'dark gritty story',
#  'dark gritty story',
#  ...]

# %%
wordcloud = WordCloud(width=1600, height=600, background_color='white', stopwords=stopword_, min_font_size=5).generate(''.join(word_cloud_common_words))

word_cloud_image = px.imshow(wordcloud)
word_cloud_image.update_layout(width=800, height=700)
word_cloud_image.show()
# Out:
# <div>                            <div id="aa013efe-45ee-4063-aaa3-72efca8f7423" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa013efe-45ee-4063-aaa3-72efca8f7423")) {                    Plotly.newPlot(                        "aa013efe-45ee-4063-aaa3-72efca8f7423",                        [{"name":"0","source":"...\u002f9\u002fdHSnpzk6ZJhSH5PDw8uec9eXPv2+TK9z3nvAiGYeDHjx8\u002ffvz48ePHjx8\u002ffvz48ePHz50KhWjw46fdoJj1p4KnwtiJU4JXEtta42jNLxcb\u002frG\u002fTuKPmB76onN7p5Na+8fZuj+Xx\u002f4gpUcQ2\u002fz46WSsmG3FlVXd+NHPxc0ntrWPjSX7tpUd\u002frH3q5HsIGKbHz9+\u002fPjxczewtfTkD\u002fn7Pui+cKQsmdh2N\u002fBW+qarisLfBzwnpvOIbbdIV5WuKziYp6k02MxcKnOELPnFhAeITi2zo\u002fzcV7m77K9JCOnU6FVOzbcdn\u002fanncfe4Xjz9\u002fIGb46roz7Lwem6zNdubHyqy+T5EcOJbX783M10jIDVYNQrjAYZk82nM4htfu4\u002f7EF9GIYS7N4wUDKrK3+w2ly3s+JTYpsfP\u002fcHaJt+O378+PHj526hqlF9saj8cnFFQW2DymBq1BsMFguPQRewmEI2MzkksF90aO+IEC6DTnynnzuSY\u002fIbZ+qy3klqbfIJw5hkGoKQiPZbaCyGV69vMNrM44N6yRh8tcUQyZYRnTwyKqB7JFumsuh+LNgvN6qIzbcd7\u002fen\u002fcfuPR319\u002fIGb4+rIz7Lj5\u002f7gfYKWBdryt+9cCxLUQsAHw0a93BCD53F\u002fP7F47O6JPULCCV6+7knuNSwm0eVJPAGExtuQUYoT3T5iWjF4aEHNkXApgjEtDBigx93eBhJP3cjFIS8vu8bRKsv7KpMldCFQyQpxIaO4zZ8xN1I2vXS59\u002f4k2h1gcGgHtrxHNHamVxUnD0mP\u002fR61\u002fcdln3Vu1DMNjV4Fs7r7mZF2sJ3u30ayAgmNvjxc+dxtbTqxxMXzhaUEhsAFDqDQmeAOkgrqdxwNo1Ooczpm7xsWF8pl0109XOHcaYuq87kSZ2x80H3hUSTM1nqMpVFtzhq9GMx44lt3iGkcXqLYgFgc+lJz4LR7cH7\u002fWn\u002fsXtPR\u002f29vMHL4+qQz7pXKdQWvZ\u002f1EcH4eMyyQeKBBOMdwmXFlf3VB6uNNTQSLZIdMSfswVBmCNHJT1tpl8p7va76oYPbSzWNQ0MiHUY2lZapqN2YdbXZz8+9RZpif6NZTrT6Qvt78GPHP5J+COytOis3NhCtHcpt+Ag\u002fncrkoBn3knrlx8\u002fdgtFifeHP\u002fQ+v+9OteuWKyWr94\u002fy1cat\u002f\u002fftKBrHt\u002fgYhGv5jUAxNU+QTrW2i1qgCgECGkNhwH3Dbjr0D\u002f17ecNuOy88dwhVF2vcFPxbpig02g8qiutF488OsT9QWNdHv3uV8w9VXbn4y7\u002fzTJboKz8a20a4IrK+unZWy2HunLRIzWBG\u002ffuawDwgMO1CSh3P0c++gssgV5kqi1Rfa34MfO\u002f6R9ENAblRUGmqJ1g7lNnyEHz9tALnjHmn9+HGiXqt78o\u002fdGZU+zzmZrNa3dx0prle8OH4Y4v+aAwAAGSFtLD62t+pyvUkVwBDOCBkwN2Io4SRwXVn0R8nxTFWZCbWGsSSTgvrMCR9CwuVnZanL91ddvq4srjEqMQwLZUkmBvWeEz6UdGuUt5ed\u002fjbv33eTF4wJ6OF411H59XfTtzwbN3VO+FAA2FVxYX\u002fV5UJtjQm1KMzaIUdfdnieHL2KfOvj7O9yNB0c8R6HwnRsAsCRmmsbi4\u002fXmVQ6qxEAPs3++9Psv+1N6\u002fs9m8ALBe\u002f2p2M5VH11V+WFMl2dwWYS0bix3KDxQb0J1cdaHedW8ebY7bS6P63+TTvq72XH8\u002f54eVxeflar44wB9lfZmX8qLtQYFRI6f0pw31iOv+YpqOo1Xz3+c0V+jby0zmyyRCeHf7jnZXGQUFWnXvP879dOZFColHGLhi18axaZQgaASeyFL\u002f\u002f25K9vblM1aBL6xr706wpJsAgAjDrTz69sPv9vGoZhw2cPWPbxfCqdSvywW+yvOUiwGGyG1LpT04KnEOz3KgPFvQaKez2Z5pRT4tbYNtolYKXVVi5J7C1msAj2ABan1qAlGP3c7Zyv35GhOlFvKgeAY\u002fJfj8l\u002ftdsHS+eOkDVFvZ6r\u002f+uEfKP9dSy379zwd+yv7XjTgzdcUx68qjhQbyonk6ihzK7DZAuCmXFEJ480mCrO1f9VoruhszZSSQwBNSBZMLqfeJrDwYKaDlT\u002fkKs+b0YNAmpgH9GUXqIJjjm\u002ffM2l9MZj1cYCjaWBSmIEMWKHyuaHsbo53n605pcc9dmn435NU+y\u002frNjTaJYzyOwUwdiRAYu97AE87qSXI+l5oFrdST8AUGWof\u002fTyB9\u002f2evH7\u002fO3levkDoSMnBw35MOuXEl31CFnvp7vMtt8xm1HL9vKjqbVX5cYGNoXZSxi\u002fMGJSEFMCABqr\u002fqELb\u002fURdn272zJ8z+cb0t\u002fPXL8i5oHpIcMBYHv50d+K\u002f7U39RN1ey9pOd7ZzoHqc\u002fuqz5br5VQSpSsv6uGICfHcpqUG\u002fio\u002fdrz2Srm+BgDWF+1eX7Tbbp8XPm5x5GRHDybU\u002fH3+9nMNN\u002fVWUxBTPCV46KSgQY6b\u002fosNGUfllwu05fWmRgaZ3oUbtiB8fBI\u002fxt7q5Ufct0glnLEjE1Vqg+OfwWAmOrWVDNWNvdU7a4zVVISSxO\u002fxUMRSCkIBgCevLn6z60fBzFAAON9w+lTdsVcS3gUAlaXxj9L1Bdo8MU2SzO\u002fh6KdEV7Sh5CelWdFPPOih8CUOuwk17ajYcqPxGgZoH+GAB0Ln2ft\u002f6uojSyJX7KrarrVqIlkxj0Q9LqA2zSGfrT95rPagwlxPRajjAqeMDZjkoR+3pNYeqTFWZahvMsnM8QFTtpZvjOMkPB6zElrox4M\u002fAFxrvHKq7pgJNfUU9JkbtohKorbUDwBcVV66qrzclZe0t\u002fofnVUzNmCSPSRNa9VsKv0lX5trw6wyeuCiyMdCmeHNe3wfM54696drn0cm+UejjdhQbOWWvW1Qrxz8diYtkM9dOLAnseG+5Jeiwyqzfog0kU6inq7L\u002fD5\u002fr8KsebJL85XoSM21DzK3hTIlk4P70snUa8qi7\u002fP33lSVfNR9oeOSt7Uk9WJDXj9x3FBpohVDT9dlfJ+\u002fV28zLY0e6+inVSLY0qkh\u002fW0Y+ ...

# %% [markdown]
# ### 단어 등장 빈도 체크

# %%
text_list = word_cloud_common_words.copy()

total_words = ''.join(text_list)
total_words = word_tokenize(total_words)
total_words
# Out:
# ['series',
#  'escapades',
#  'demonstrating',
#  'adage',
#  'that',
#  'what',
#  'good',
#  'goose',
#  'also',
#  'good',
#  'gander',
#  'some',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storyseries',
#  'escapades',
#  'demonstrating',
#  'adage',
#  'that',
#  'what',
#  'good',
#  'gooseseriesseriesescapades',
#  'demonstrating',
#  'adage',
#  'that',
#  'what',
#  'good',
#  'gooseescapades',
#  'demonstrating',
#  'adage',
#  'that',
#  'what',
#  'good',
#  'gooseescapadesdemonstrating',
#  'adage',
#  'that',
#  'what',
#  'good',
#  'goosedemonstrating',
#  'adagedemonstratingadageadagethat',
#  'what',
#  'good',
#  'goosethatwhat',
#  'good',
#  'goosewhatgood',
#  'goosegood',
#  'goosegoodgoosegoosegoosealso',
#  'good',
#  'gander',
#  'some',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storyalso',
#  'good',
#  'gander',
#  'some',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storyalsoalsogood',
#  'gander',
#  'some',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storygander',
#  'some',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storygander',
#  'some',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storygandergandergandersome',
#  'which',
#  'occasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storysome',
#  'whichsomewhichwhichoccasionally',
#  'amuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storyoccasionallyamuses',
#  'none',
#  'which',
#  'amounts',
#  'much',
#  'storyamusesnone',
#  'which',
#  'amounts',
#  'much',
#  'storynone',
#  'which',
#  'amounts',
#  'much',
#  'storynonewhich',
#  'amounts',
#  'much',
#  'storywhich',
#  'amounts',
#  'much',
#  'storyamounts',
#  'much',
#  'storyamountsmuch',
#  'storymuch',
#  'storymuchstorystorystoryThis',
#  'quiet',
#  'introspective',
#  'entertaining',
#  'independent',
#  'worth',
#  'seekingThis',
#  'quiet',
#  'introspective',
#  'entertaining',
#  'independentThisquiet',
#  'introspective',
#  'entertaining',
#  'independentquiet',
#  'introspective',
#  'entertainingquietintrospective',
#  'entertainingintrospective',
#  'entertainingintrospectiveintrospectiveentertainingindependentworth',
#  'seekingworth',
#  'seekingworthworthseekingEven',
#  'fans',
#  'Ismail',
#  'Merchant',
#  'work',
#  'suspect',
#  'would',
#  'have',
#  'hard',
#  'time',
#  'sitting',
#  'through',
#  'thisEven',
#  'fans',
#  'Ismail',
#  'Merchant',
#  'workEven',
#  'fansEvenfansIsmail',
#  'Merchant',
#  'workIsmail',
#  'Merchant',
#  'workIsmail',
#  'MerchantIsmailMerchantMerchantworksuspect',
#  'would',
#  'have',
#  'hard',
#  'time',
#  'sitting',
#  'through',
#  'thissuspectsuspectsuspectsuspectwould',
#  'have',
#  'hard',
#  'time',
#  'sitting',
#  'through',
#  'thiswould',
#  'have',
#  'hard',
#  'time',
#  'sitting',
#  'through',
#  'thiswouldhave',
#  'hard',
#  'time',
#  'sitting',
#  'through',
#  'thishavehard',
#  'time',
#  'sitting',
#  'through',
#  'thishard',
#  'timehard',
#  'timehardtimesitting',
#  'through',
#  'thissittingthrough',
#  'thisthroughthispositively',
#  'thrilling',
#  'combination',
#  'ethnography',
#  'intrigue',
#  'betrayal',
#  'deceit',
#  'murder',
#  'Shakespearean',
#  'tragedy',
#  'juicy',
#  'soap',
#  'operapositively',
#  'thrilling',
#  'combination',
#  'ethnography',
#  'intrigue',
#  'betrayal',
#  'deceit',
#  'murder',
#  'Shakespearean',
#  'tragedy',
#  'juicy',
#  'soap',
#  'operapositively',
#  'thrilling',
#  'combination',
#  'ethnography',
#  'intrigue',
#  'betrayal',
#  'deceit',
#  'murderpositively',
#  'thrilling',
#  'combinationpositively',
#  'thrilling',
#  'combinationpositivelythrilling',
#  'combinationthrillingcombinationethnography',
#  'intrigue',
#  'betrayal',
#  'deceit',
#  'murderethnography',
#  'intrigue',
#  'betrayal',
#  'deceit',
#  'murderethnographyethnographyintrigue',
#  'betrayal',
#  'deceit',
#  'murderintrigue',
#  'betrayal',
#  'deceit',
#  'murderintrigue',
#  'betrayal',
#  'deceit',
#  'murderintriguebetrayal',
#  'deceit',
#  'murderbetrayal',
#  'deceit',
#  'murderbetrayaldeceit',
#  'murderdeceit',
#  'murderdeceitdeceitmurderShakespearean',
#  'tragedy',
#  'juicy',
#  'soap',
#  'operaShakespearean',
#  'tragedy',
#  'juicy',
#  'soap',
#  'operaShakespearean',
#  'tragedyShakespearean',
#  'tragedyShakespearean',
#  'tragedyShakespeareantragedyjuicy',
#  'soap',
#  'operajuicy',
#  'soap',
#  'operajuicysoap',
#  'operasoapoperaAggressive',
#  'selfglorification',
#  'manipulative',
#  'whitewashAggressive',
#  'selfglorification',
#  'manipulative',
#  'whitewashAggressiveselfglorification',
#  'manipulative',
#  'whitewashselfglorificationselfglorificationmanipulative',
#  'whitewashmanipulative',
#  'whitewashmanipulativewhitewashcomedydrama',
#  'nearly',
#  'epic',
#  'proportions',
#  'rooted',
#  'sincere',
#  'performance',
#  'title',
#  'character',
#  'undergoing',
#  'midlife',
#  'crisiscomedydrama',
#  'nearly',
#  'epic',
#  'proportionscomedydramacomedydramanearly',
#  'epic',
#  'proportionsnearly',
#  'epic',
#  'proportionsnearly',
#  'epicnearlyepicproportionsrooted',
#  'sincere',
#  'performance',
#  'title',
#  'character',
#  'undergoing',
#  'midlife',
#  'crisisrooted',
#  'sincere',
#  'performance',
#  'title',
#  'character',
#  'undergoing',
#  'midlife',
#  'crisisrooted',
#  'sincere',
#  'performancerootedsincere',
#  'performancesincere',
#  'performancesincere',
#  'performancesincereperformancetitle',
#  'character',
#  'undergoing',
#  'midlife',
#  'crisistitle',
#  'character',
#  'undergoing',
#  'midlife',
#  'crisistitle',
#  'charactertitle',
#  'charactertitlecharacterundergoing',
#  'midlife',
#  'crisisundergoingmidlife',
#  'crisismidlifecrisisNarratively',
#  'Trouble',
#  'Every',
#  'plodding',
#  'messNarrativelyTrouble',
#  'Every',
#  'plodding',
#  'messTrouble',
#  'Every',
#  'plodding',
#  'messTrouble',
#  'EveryTroubleEveryEveryplodding',
#  'messplodding',
#  'messplodding',
#  'messplodding',
#  'messploddingmessImportance',
#  'Being',
#  'Earnest',
#  'thick',
#  'with',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'QuotationsImportanceImportanceBeing',
#  'Earnest',
#  'thick',
#  'with',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'QuotationsBeing',
#  'Earnest',
#  'thick',
#  'with',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'QuotationsBeingEarnest',
#  'thick',
#  'with',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'QuotationsEarnestEarnestthick',
#  'with',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationsthick',
#  'with',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationsthickwith',
#  'plays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationswithplays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationsplays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationsplays',
#  'like',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationsplayslike',
#  'reading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationslikereading',
#  'from',
#  'Bartlett',
#  'Familiar',
#  'Quotationsreadingreadingfrom',
#  'Bartlett',
#  'Familiar',
#  'QuotationsfromBartlett',
#  'Familiar',
#  'QuotationsBartlettBartlettFamiliar',
#  'QuotationsFamiliarQuotationsdoes',
#  'leave',
#  'with',
#  'muchdoes',
#  'leave',
#  'with',
#  'muchdoes',
#  'leave',
#  'with',
#  'muchdoes',
#  'leave',
#  'with',
#  'muchdoesdoesleave',
#  'with',
#  'muchleaveleavewith',
#  'muchcould',
#  'hate',
#  'same',
#  'reasoncould',
#  'hate',
#  'same',
#  'reasoncould',
#  'hate',
#  'same',
#  'reasoncouldhate',
#  'same',
#  'reasonhatehatesame',
#  'reasonsame',
#  'reasonsame',
#  'reasonsamereasonThere',
#  'little',
#  'recommend',
#  'Snow',
#  'Dogs',
#  'unless',
#  'considers',
#  'cliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilarityTherelittle',
#  'recommend',
#  'Snow',
#  'Dogs',
#  'unless',
#  'considers',
#  'cliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilaritylittle',
#  'recommend',
#  'Snow',
#  'Dogs',
#  'unless',
#  'considers',
#  'cliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilaritylittle',
#  'recommend',
#  'Snow',
#  'Dogslittle',
#  'recommend',
#  'Snow',
#  'Dogslittle',
#  'recommend',
#  'Snow',
#  'Dogslittlerecommend',
#  'Snow',
#  'Dogsrecommend',
#  'Snow',
#  'DogsrecommendSnow',
#  'DogsSnowDogsunless',
#  'considers',
#  'cliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilarityunlessconsiders',
#  'cliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilarityconsiders',
#  'cliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilarityconsiderscliched',
#  'dialogue',
#  'perverse',
#  'escapism',
#  'source',
#  'high',
#  'hilaritycliched',
#  'dialogue',
#  'perverse',
#  'escapismcliched',
#  'dialoguecliched',
#  'dialogueclicheddialogueperverse',
#  'escapismperverseescapismsource',
#  'high',
#  'hilaritysourcesourcehigh',
#  'hilarityhigh',
#  'hilarityhighhilarityKung',
#  'Oedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flick',
#  'proves',
#  'that',
#  'sometimes',
#  'dreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatKungKungOedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flick',
#  'proves',
#  'that',
#  'sometimes',
#  'dreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatOedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flick',
#  'proves',
#  'that',
#  'sometimes',
#  'dreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatOedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flickOedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flickOedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flickOedekerk',
#  'realization',
#  'childhood',
#  'dream',
#  'martialarts',
#  'flickOedekerk',
#  'realization',
#  'childhood',
#  'dreamOedekerk',
#  'realizationOedekerkOedekerkrealizationchildhood',
#  'dreamchildhood',
#  'dreamchildhood',
#  'dreamchildhooddreammartialarts',
#  'flickmartialarts',
#  'flickmartialarts',
#  'flickmartialarts',
#  'flickmartialarts',
#  'flickmartialartsflickproves',
#  'that',
#  'sometimes',
#  'dreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatprovesthat',
#  'sometimes',
#  'dreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatsometimes',
#  'dreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatsometimesdreams',
#  'youth',
#  'should',
#  'remain',
#  'just',
#  'thatdreams',
#  'youthdreamsdreamsyouthyouthshould',
#  'remain',
#  'just',
#  'thatshouldremain',
#  'just',
#  'thatremainjust',
#  'thatjustperformances',
#  'absoluteperformancesperformancesabsoluteabsoluteabsoluteabsoluteabsoluteFresnadillo',
#  'something',
#  'serious',
#  'about',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'senseFresnadillosomething',
#  'serious',
#  'about',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensesomething',
#  'serious',
#  'about',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensesomething',
#  'serious',
#  'about',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensesomethingserious',
#  'about',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'senseseriousabout',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'senseabout',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'senseabout',
#  'ways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'senseaboutways',
#  'which',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensewayswayswhich',
#  'extravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensewhichextravagant',
#  'chance',
#  'distort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'senseextravagant',
#  'chanceextravagantchancedistort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensedistort',
#  'perspective',
#  'throw',
#  'path',
#  'good',
#  'sensedistort',
#  'perspectivedistort',
#  'perspectivedistortperspectiveperspectivethrow',
#  'path',
#  'good',
#  'sensethrowthrowpath',
#  'good',
#  'sensepath',
#  'good',
#  'sensepathpathgood',
#  'sensegood',
#  'sensesensestill',
#  'like',
#  'Moonlight',
#  'Mile',
#  'better',
#  'judgment',
#  'damnedstill',
#  'like',
#  'Moonlight',
#  'Mile',
#  'better',
#  'judgment',
#  'damnedstilllike',
#  'Moonlight',
#  'Mile',
#  'better',
#  'judgment',
#  'damnedlike',
#  'Moonlight',
#  'Mile',
#  'better',
#  'judgment',
#  'damnedMoonlight',
#  'Mile',
#  'better',
#  'judgment',
#  'damnedMoonlight',
#  'Mile',
#  'better',
#  'judgmentMoonlightMile',
#  'better',
#  'judgmentMilebetter',
#  'judgmentbetter',
#  'judgmentbetterjudgmentdamneddamnedwelcome',
#  'relief',
#  'from',
#  'baseball',
#  'movies',
#  'that',
#  'hard',
#  'mythic',
#  'this',
#  'sweet',
#  'modest',
#  'ultimately',
#  'winning',
#  'storywelcome',
#  'relief',
#  'from',
#  'baseball',
#  'movies',
#  'that',
#  'hard',
#  'mythicwelcome',
#  'reliefwelcome',
#  'reliefwelcomerelieffrom',
#  'baseball',
#  'movies',
#  'that',
#  'hard',
#  'mythicbaseball',
#  'movies',
#  'that',
#  'hard',
#  'mythicbaseball',
#  'moviesbaseballmoviesthat',
#  'hard',
#  'mythichard',
#  'mythichard',
#  'mythichard',
#  'mythicmythicmythicmythicthis',
#  'sweet',
#  'modest',
#  'ultimately',
#  'winning',
#  'storythis',
#  'sweet',
#  'modest',
#  'ultimately',
#  'winning',
#  'storysweet',
#  'modest',
#  'ultimately',
#  'winning',
#  'storysweet',
#  'modest',
#  'ultimately',
#  'winning',
#  'storysweet',
#  'modest',
#  'ultimately',
#  'winning',
#  'storysweet',
#  'modestsweet',
#  'modestsweet',
#  'modestsweetsweetmodestultimately',
#  'winning',
#  'storyultimatelywinning',
#  'storywinningbilingual',
#  'charmer',
#  'just',
#  'like',
#  'woman',
#  'inspiredbilingual',
#  'charmerbilingual',
#  'charmerbilingual',
#  'charmerbilingualcharmerjust',
#  'like',
#  'woman',
#  'inspiredlike',
#  'woman',
#  'inspiredwoman',
#  'inspiredwomanwomaninspiredinspiredinspiredLike',
#  'less',
#  'dizzily',
#  'gorgeous',
#  'companion',
#  'Wong',
#  'Mood',
#  'Love',
#  'very',
#  'much',
#  'Hong',
#  'Kong',
#  'movie',
#  'despite',
#  'mainland',
#  'settingLike',
#  'less',
#  'dizzily',
#  'gorgeous',
#  'companionless',
#  'dizzily',
#  'gorgeous',
#  'companionless',
#  'dizzily',
#  'gorgeous',
#  'companionless',
#  'dizzily',
#  'gorgeous',
#  'companionless',
#  'dizzily',
#  'gorgeouslessdizzily',
#  'gorgeousdizzilygorgeouscompanionWong',
#  'Mood',
#  'Love',
#  'very',
#  'much',
#  'Hong',
#  'Kong',
#  'movie',
#  'despite',
#  'mainland',
#  'settingWongMood',
#  'Love',
#  'very',
#  'much',
#  'Hong',
#  'Kong',
#  'movie',
#  'despite',
#  'mainland',
#  'settingMood',
#  'Love',
#  'very',
#  'much',
#  'Hong',
#  'Kong',
#  'movie',
#  'despite',
#  'mainland',
#  'settingMood',
#  'Love',
#  'very',
#  'much',
#  'Hong',
#  'Kong',
#  ...]

# %%
freq_words = FreqDist(total_words)
freq_words
# Out:
# FreqDist({'that': 9438, 'with': 6133, 'this': 3449, 'film': 3435, 'movie': 3077, 'than': 2919, 'from': 2803, 'more': 2644, 'about': 2616, 'have': 2261, ...})

# %%
word_frequency = FreqDist(freq_words)

# %%
word_frequency
# Out:
# FreqDist({'that': 9438, 'with': 6133, 'this': 3449, 'film': 3435, 'movie': 3077, 'than': 2919, 'from': 2803, 'more': 2644, 'about': 2616, 'have': 2261, ...})

# %%
len(freq_words), len(word_frequency)
# Out:
# (97196, 97196)

# %%
mode_20 = px.bar(pd.DataFrame(word_frequency, index=[0]).T.sort_values(by=[0], ascending=False).head(20))
mode_20.update_layout(width=1000, height=600)
mode_20.update_yaxes(tickformat=",")
mode_20.show()
# Out:
# <div>                            <div id="3dd5dbbd-bf99-4027-b1fd-579829c58366" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dd5dbbd-bf99-4027-b1fd-579829c58366")) {                    Plotly.newPlot(                        "3dd5dbbd-bf99-4027-b1fd-579829c58366",                        [{"alignmentgroup":"True","hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["that","with","this","film","movie","than","from","more","about","have","like","into","their","your","most","story","much","good","what","some"],"xaxis":"x","y":[9438,6133,3449,3435,3077,2919,2803,2644,2616,2261,2090,1758,1445,1364,1274,1250,1237,1208,1191,1151],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line": ...

# %% [markdown]
# ### 부정적인 감성을 표현할 때 자주 사용된 단어

# %%
neg_text_list = []
for idx, row in train[train['sentiment_class']=='negative'].iterrows():
    neg_text_list.append(row['Phrase'])

neg_text_list
# Out:
# ['would have hard time sitting through this',
#  'have hard time sitting through this',
#  'Aggressive selfglorification manipulative whitewash',
#  'selfglorification manipulative whitewash',
#  'Trouble Every plodding mess',
#  'plodding mess',
#  'plodding mess',
#  'could hate same reason',
#  'hate',
#  'hate',
#  'Oedekerk realization childhood dream martialarts flick proves that sometimes dreams youth should remain just that',
#  'baseball movies that hard mythic',
#  'Hampered paralyzed selfindulgent script that aims poetry ends sounding like satire',
#  'selfindulgent script',
#  'There very little sense what going here',
#  'avoid',
#  'almost feels movie more interested entertaining itself than amusing',
#  'movie progression into rambling incoherence gives meaning phrase fatal script error',
#  'movie progression into rambling incoherence',
#  'gives meaning phrase fatal script error',
#  'fatal script error',
#  'fatal script error',
#  'Tartakovsky team some freakish powers visual charm five writers slip into modern narrative banality',
#  'narrative banality',
#  'sure filmmaker would disagree honestly point',
#  'honestly point',
#  'clunky TVmovie approach',
#  'Thanks largely Williams interesting developments processed minutes rest just overexposed waste film',
#  'rest just overexposed waste film',
#  'just overexposed waste film',
#  'overexposed waste film',
#  'overexposed waste',
#  'Comes across relic from bygone convolutions feel silly rather than plausible',
#  'relic from bygone convolutions feel silly rather than plausible',
#  'your lives',
#  'your lives',
#  'makes your teeth hurt',
#  'generic villains lack intrigue other than their funny accents action scenes poorly delivered',
#  'generic villains lack intrigue other than their funny accents',
#  'Downright transparent script endless assault embarrassingly hamfisted jokes that reek script rewrite designed garner film cooler PG13 rating',
#  'script endless assault embarrassingly hamfisted jokes that reek script rewrite designed garner film cooler PG13 rating',
#  'script endless assault embarrassingly hamfisted jokes that reek script rewrite designed garner film cooler PG13 rating',
#  'script endless assault embarrassingly hamfisted jokes',
#  'endless assault',
#  'embarrassingly hamfisted jokes',
#  'impossible',
#  'goes overboard with loony melodramatic denouement which high school swimming pool substitutes bathtub',
#  'directed barely',
#  'lazy movie avoid solving problem trying distract with solution another',
#  'lazy movie',
#  'music comic antics through perverse pleasure watching Disney scrape bottom cracker barrel',
#  'Disney scrape bottom cracker barrel',
#  'Scarcely worth mention apart from reporting number tumbleweeds blowing through empty theatres graced with company',
#  'Scarcely worth mention apart from reporting number tumbleweeds blowing through empty theatres',
#  'Scarcely worth mention',
#  'Scarcely worth',
#  'apart from reporting number tumbleweeds blowing through empty theatres',
#  'number tumbleweeds blowing through empty theatres',
#  'tumbleweeds blowing through empty theatres',
#  'tumbleweeds blowing through empty theatres',
#  'Analyze That those crass contrived sequels that only fails makes secondguess your affection original',
#  'Analyze That those crass contrived sequels that only fails makes secondguess your affection original',
#  'those crass contrived sequels that only fails makes secondguess your affection original',
#  'those crass contrived sequels that only fails makes secondguess your affection original',
#  'those crass contrived sequels that only fails makes secondguess your affection original',
#  'those crass contrived sequels that only fails makes secondguess your affection original',
#  'those crass contrived sequels',
#  'crass contrived sequels',
#  'that only fails makes secondguess your affection original',
#  'fails makes secondguess your affection original',
#  'fails',
#  'particularly good film',
#  'comedy equivalent Saddam Hussein just about ready permission preemptive strike',
#  'comedy equivalent Saddam Hussein just about ready permission preemptive strike',
#  'consistently unimaginative that probably only have saved film with those wisecracking Mystery Science Theater 3000 guys',
#  'consistently unimaginative that probably only have saved film with those wisecracking Mystery Science Theater 3000 guys',
#  'mawkish selfparody that plays like some weird Masterpiece Theater sketch with neither point view compelling reason being',
#  'Takes character like another believe puts them into battle wills that impossible care about very funny',
#  'like',
#  'another believe puts them into battle wills that impossible care about very funny',
#  'impossible care about very funny',
#  'then knock yourself enjoy screen postcard that selfglorified Martin Lawrence lovefest',
#  'whole film this sneaky feel director trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'this sneaky feel director trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'director trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'director trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'director trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'director trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'trying dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'dupe viewer into taking Very Important simply because movie ugly look Hollywood product',
#  'simply because movie ugly look Hollywood product',
#  'movie ugly look Hollywood product',
#  'ugly look Hollywood product',
#  'bogged down earnest dramaturgy',
#  'cheap',
#  'Violent vulgar forgettably',
#  'vulgar',
#  'expense those paid those',
#  'hard might enjoy this',
#  'hard might enjoy this',
#  'movie silly beyond comprehension even were silly would still beyond comprehension',
#  'movie silly beyond comprehension',
#  'Poor editing bluescreen ultracheesy dialogue highlight radical action',
#  'Poor editing bluescreen ultracheesy dialogue',
#  'Poor editing bluescreen',
#  'Poor editing bluescreen',
#  'bluescreen',
#  'completely misses emotions',
#  'failing ultimately',
#  'failing ultimately',
#  'There scientific discerned here that producers would well heed Mediocre movies start drag soon action speeds when explosions start they fall pieces',
#  'There scientific discerned here that producers would well heed Mediocre movies start drag soon action speeds when explosions start they fall pieces',
#  'There scientific discerned here that producers would well heed Mediocre movies start drag soon action speeds',
#  'stale uninspired',
#  'uninspired',
#  'uninspired',
#  'wears welcome tryingly title character',
#  'could force scratch hole your head',
#  'could force scratch hole your head',
#  'scratch hole your head',
#  'convoluted',
#  'violence',
#  'reason exist other than employ Hollywood kids people favors their famous parents',
#  'Nothing more than amiable unfocused bagatelle that plays like looselyconnected string actingworkshop exercises',
#  'unfocused',
#  'dull',
#  'Starts mediocre spirals downward thuds bottom pool with utterly incompetent conclusion',
#  'spirals downward thuds bottom pool with utterly incompetent conclusion',
#  'pool with utterly incompetent conclusion',
#  'pool with utterly incompetent conclusion',
#  'with utterly incompetent conclusion',
#  'utterly incompetent conclusion',
#  'utterly incompetent conclusion',
#  'utterly incompetent',
#  'Horrendously amateurish filmmaking that plainly dull visually ugly when incomprehensible',
#  'filmmaking that plainly dull visually ugly when incomprehensible',
#  'filmmaking that plainly dull visually ugly when incomprehensible',
#  'plainly dull visually ugly when incomprehensible',
#  'plainly dull visually ugly',
#  'awkwardly contrived exercise magic realism',
#  'great deal corny dialogue preposterous moments',
#  'corny dialogue preposterous moments',
#  'corny dialogue preposterous moments',
#  'preposterous',
#  'film rehashes several themes capped with pointless extremes insanely violent very graphic',
#  'capped with pointless extremes',
#  'capped with pointless extremes',
#  'with pointless extremes',
#  'pointless',
#  'disappointed',
#  'never plays dramatic even when dramatic things happen people',
#  'generates plot points with degree randomness usually achieved only lottery drawing',
#  'depress about life itself',
#  'depress',
#  'smug selfsatisfaction',
#  'pomposity pretentiousness',
#  'depressing ruthlessly pained depraved movie equivalent staring into open wound',
#  'depressing ruthlessly pained depraved',
#  'depressing',
#  'depraved',
#  'movie equivalent staring into open wound',
#  'instead opts routine slasher film that probably more make than through',
#  'routine slasher film that probably more make than through',
#  'Would been nice screenwriters trusted audiences understand complex story left film predictable denouement',
#  'superfluous sequel plagued that familiar feeling this thing over with Everyone shown appointed time place',
#  'superfluous sequel plagued that familiar feeling this thing over with Everyone shown appointed time place',
#  'superfluous sequel plagued that familiar feeling this thing over with Everyone shown appointed time place',
#  'superfluous sequel',
#  'superfluous sequel',
#  'that familiar feeling this thing over with',
#  'this thing over with',
#  'familiar antifeminist equation career kids misery tiresome romanticcomedy duds',
#  'romanticcomedy duds',
#  'Plays like blend overripe episode Dawson Creek recycled dumbeddown version Love Story',
#  'like blend overripe episode Dawson Creek recycled dumbeddown version Love Story',
#  'blend overripe episode Dawson Creek recycled dumbeddown version Love Story',
#  'overripe episode Dawson Creek recycled dumbeddown version Love Story',
#  'overripe episode Dawson Creek',
#  'recycled dumbeddown version Love Story',
#  'recycled dumbeddown version',
#  'covers huge heavy topics bland surfacey that does offer insight into instance good things happen people',
#  'huge heavy topics bland surfacey that does offer insight into instance good things happen people',
#  'bland surfacey that does offer insight into instance good things happen people',
#  'film does improve upon experience staring blank screen',
#  'does improve upon experience staring blank screen',
#  'does improve upon experience staring blank screen',
#  'does improve upon experience staring blank screen',
#  'experience staring blank screen',
#  'difficult imagine that more confused less interesting more sloppily made film could possibly come down road 2002',
#  'difficult imagine that more confused less interesting more sloppily made film could possibly come down road 2002',
#  'difficult imagine that more confused less interesting more sloppily made film could possibly come down road 2002',
#  'imagine that more confused less interesting more sloppily made film could possibly come down road 2002',
#  'more confused less interesting more sloppily made film could possibly come down road 2002',
#  'more confused less interesting more sloppily',
#  'more confused less interesting more',
#  'lackadaisical plotting mindless action',
#  'lackadaisical plotting mindless action',
#  'plotting mindless',
#  'About Benjamins evokes bottom tier blaxploitation flicks from 1970s',
#  'evokes bottom tier blaxploitation flicks from 1970s',
#  'that would fighting urge doze',
#  'that would fighting urge doze',
#  'would fighting urge doze',
#  'fighting urge doze',
#  'Thoughtless random superficial humour very Scouse accents',
#  'Thoughtless random superficial humour',
#  'very Scouse accents',
#  'Feels strangely hollow emotional core',
#  'hollow emotional core',
#  'time when commercialism squeezed life whatever idealism American moviemaking ever',
#  'when commercialism squeezed life whatever idealism American moviemaking ever',
#  'squeezed life whatever idealism American moviemaking ever',
#  'Blackandwhite unrealistic',
#  'only camouflage Carvey should considering paper wear over head when goes into public avoid being recognized bilked unsuspecting moviegoers',
#  'paper wear over head when goes into public avoid being recognized bilked unsuspecting moviegoers',
#  'paper wear over head when goes into public avoid being recognized bilked unsuspecting moviegoers',
#  'paper wear over head when goes into public avoid being recognized bilked unsuspecting moviegoers',
#  'paper wear over head when goes into public avoid being recognized bilked unsuspecting moviegoers',
#  'when goes into public avoid being recognized bilked unsuspecting moviegoers',
#  'avoid being recognized bilked unsuspecting moviegoers',
#  'bites more than chew linking massacre',
#  'largely bogus story',
#  'bogus story',
#  'become apparent that franchise best years long past',
#  'become apparent that franchise best years long past',
#  'franchise best years long past',
#  'small easily overshadowed predictability',
#  'jokes flat action looks fake',
#  'jokes flat',
#  'Festers just such dungpile that swear were watching monkeys flinging their feces',
#  'Festers just such dungpile that swear',
#  'just such dungpile',
#  'such dungpile',
#  'were watching monkeys flinging their feces',
#  'flinging their feces',
#  'their feces',
#  'addition overcooked hamfisted direction which actors reaching back dialogue sounds like horrible poetry',
#  'overcooked hamfisted direction which actors reaching back',
#  'overcooked hamfisted direction which actors reaching back',
#  'dialogue sounds like horrible poetry',
#  'dialogue sounds like horrible poetry',
#  'sounds like horrible poetry',
#  'horrible',
#  'vile incoherent mess scummy ripoff David Cronenberg brilliant Videodrome',
#  'vile incoherent mess',
#  'vile incoherent mess',
#  'vile incoherent',
#  'scummy ripoff David Cronenberg brilliant Videodrome',
#  'scummy ripoff David Cronenberg brilliant Videodrome',
#  'scummy ripoff David Cronenberg brilliant Videodrome',
#  'scummy ripoff David Cronenberg',
#  'scummy ripoff',
#  'ripoff',
#  'movie that tries smart kinda dumb',
#  'Blade just does',
#  'just does',
#  'arch rather coldblooded comedy',
#  'rather thinlyconceived movie',
#  'lack emphasis music Britney Spears first movie',
#  'dreary movie',
#  'dreary movie',
#  'they generate enough heat this cold vacuum comedy start reaction',
#  'they generate enough heat this cold vacuum comedy start reaction',
#  'generate enough heat this cold vacuum comedy start reaction',
#  'filmmakers Ivan prince fellow comes across shallow glib though meanspirited there indication that been responsible putting together movies particular value merit',
#  'shallow glib',
#  'Allen been making piffle long while',
#  'saying that piffle that airhead movie business deserves from right',
#  'that piffle that airhead movie business deserves from right',
#  'most what passes movies look like cheap hysterics',
#  'what passes movies look like cheap hysterics',
#  'passes movies look like cheap hysterics',
#  'movies look like cheap hysterics',
#  'look like cheap hysterics',
#  'Uneven performances spotty script',
#  'irritating soulsearching garbage',
#  'irritating soulsearching garbage',
#  'irritating',
#  'soulsearching garbage',
#  'garbage',
#  'comparison earlier films seems disappointingly thin slice lowerclass London life despite title amounts surprisingly little',
#  'seems disappointingly thin slice lowerclass London life despite title amounts surprisingly little',
#  'disappointingly thin',
#  'disappointingly',
#  'appears have been made people whom idea narrative logic cohesion entirely foreign concept',
#  'appears have been made people whom idea narrative logic cohesion entirely foreign concept',
#  'appears have been made people whom idea narrative logic cohesion entirely foreign concept',
#  'have been made people whom idea narrative logic cohesion entirely foreign concept',
#  'have been made people whom idea narrative logic cohesion entirely foreign concept',
#  'made people whom idea narrative logic cohesion entirely foreign concept',
#  'dreadful',
#  'better celebration these unfairly dismissed heroes would film that this painfully forced false fabricated',
#  'dismissed heroes would film that this painfully forced false fabricated',
#  'would film that this painfully forced false fabricated',
#  'that this painfully forced false fabricated',
#  'this painfully forced false fabricated',
#  'this painfully forced false fabricated',
#  'painfully forced false fabricated',
#  'painfully',
#  'relative letdown',
#  'relative letdown',
#  'letdown',
#  'monumental achievement practically every facet inept filmmaking joyless idiotic annoying heavyhanded visually atrocious often downright creepy',
#  'joyless idiotic annoying heavyhanded visually atrocious often downright creepy',
#  'joyless idiotic annoying heavyhanded',
#  'joyless idiotic annoying heavyhanded',
#  'joyless',
#  'idiotic',
#  'annoying heavyhanded',
#  'annoying',
#  'visually atrocious often downright creepy',
#  'visually atrocious',
#  'atrocious',
#  'most highlypraised disappointments misfortune watch quite some time',
#  'most highlypraised disappointments',
#  'disappointments',
#  'Remember back when thrillers actually thrilled',
#  'Fails fundamentally every conventional level',
#  'probably accurate call movie',
#  'abhorrent',
#  'abhorrent',
#  'more like hell',
#  'hell',
#  'Purports Hollywood satire winds kind film that should target something',
#  'Hollywood satire winds kind film that should target something',
#  'unsophisticated',
#  'Stupid infantile redundant sloppy overthetop amateurish',
#  'Stupid infantile redundant sloppy',
#  'Stupid infantile redundant sloppy',
#  'Stupid',
#  'Stupid',
#  'infantile redundant sloppy',
#  'redundant sloppy',
#  'sloppy',
#  'sloppy',
#  'overthetop amateurish',
#  'overthetop amateurish',
#  'movie resolutely avoids comic possibilities situation becomes more dumb high school comedy about gags prom dates',
#  'avoids comic possibilities situation becomes more dumb high school comedy about gags prom dates',
#  'avoids comic possibilities situation becomes more dumb high school comedy about gags prom dates',
#  'more dumb high school comedy about gags prom dates',
#  'Once expectation laughter been quashed whatever obscenity hand even funniest idea funny',
#  'every cheap trick book trying make outrage',
#  'Just bunch good actors flailing around caper that neither original terribly funny',
#  'terribly',
#  'This illconceived expensive project winds looking like bunch talented thesps slumming',
#  'illconceived expensive project',
#  'shallow offensive redundant with pitifully real laughs',
#  'shallow offensive redundant with pitifully real laughs',
#  'shallow offensive redundant',
#  'shallow offensive redundant',
#  'offensive redundant',
#  'everybody else background just seems manufactured artificial',
#  'Kathie Gifford film directors sadly proving once again does always hand hand with talent',
#  'Kathie Gifford film directors',
#  'trash',
#  'Loses sense humor failed jokes twitchy acting general boorishness',
#  'failed jokes twitchy acting general boorishness',
#  'failed jokes twitchy acting general boorishness',
#  'failed jokes twitchy acting',
#  'failed',
#  'winds mired teardrenched quicksand',
#  'final effect like having guys yelling your face hours',
#  'having guys yelling your face hours',
#  'guys yelling your face hours',
#  'assembled cliches pabulum that plays like 95minute commercial properties',
#  'plays like 95minute commercial properties',
#  '95minute commercial',
#  '95minute commercial',
#  'ambitious serious film that manages virtually everything wrong sitting through something akin cinematic penance',
#  'that manages virtually everything wrong',
#  'manages virtually everything wrong',
#  'virtually everything wrong',
#  'sitting through something akin cinematic penance',
#  'Anyone suffers through this film deserves very least consolation candy',
#  'Anyone suffers through this film',
#  'walked away from this version',
#  'Attal pushes hard make this comedy serious drama',
#  'case actors everything humanly possible create characters sweet believable defeated screenplay that forces them into bizarre implausible behavior',
#  'defeated screenplay that forces them into bizarre implausible behavior',
#  'forces them into bizarre implausible behavior',
#  'Carvey characters both overplayed exaggerated then again subtlety never been trademark',
#  'characters both overplayed exaggerated',
#  'both overplayed exaggerated',
#  'overplayed exaggerated',
#  'doublebarreled ripoff',
#  'ripoff',
#  'frustratingly refuses give Pinochet crimes political context',
#  'crimes',
#  'nightmare',
#  'incessant',
#  'Obvious obnoxious didactic burlesque',
#  'Obvious obnoxious didactic burlesque',
#  'flat scruffy sands titular community',
#  'young stars cute story ensuing complications manipulative message blatant resolutions convenient',
#  'characteristically engorged sloppy',
#  'kind film that could only made AfricanAmericans because broad racial insensitivity towards AfricanAmericans',
#  'that could only made AfricanAmericans because broad racial insensitivity towards AfricanAmericans',
#  'begins Seven ripoff',
#  'extremely unpleasant film',
#  'extremely unpleasant film',
#  'extremely unpleasant film',
#  'extremely unpleasant',
#  'pile useless actioners from schmucks know tell story more than four minutes',
#  'pile useless actioners from schmucks know tell story more than four minutes',
#  'pile useless actioners',
#  'schmucks know tell story more than four minutes',
#  'schmucks',
#  'first time that director Sara Sugarman stoops having characters drop their pants laughs last time fails provoke them',
#  'left thinking only reason make movie because present standards allow plenty nudity',
#  'This overproduced piece dreck shockingly absolutely unnecessary',
#  'This overproduced piece dreck',
#  'shockingly absolutely unnecessary',
#  'shockingly absolutely unnecessary',
#  'shockingly absolutely unnecessary',
#  'shockingly',
#  'flawed compromised',
#  'comes annoying rather than charming',
#  'comes annoying rather than charming',
#  'throwntogether feel summercamp talent show hastily written underrehearsed arbitrarily plotted filled with crude humor vulgar innuendo',
#  'throwntogether feel summercamp talent show hastily written underrehearsed arbitrarily plotted filled with crude humor vulgar innuendo',
#  'throwntogether feel summercamp talent show hastily written underrehearsed arbitrarily plotted',
#  'throwntogether feel summercamp talent show hastily written underrehearsed arbitrarily plotted',
#  'crude humor vulgar innuendo',
#  'essence magic makebelieve promise life that soars above material realm this opposite truly magical movie',
#  'this opposite truly magical movie',
#  'this opposite truly magical movie',
#  'opposite truly magical movie',
#  'hamstrung badly handled screenplay what really amusing concept hightech that transforms wearer into superman',
#  'badly handled screenplay',
#  'badly handled screenplay',
#  'seem disappointing generalities',
#  'disappointing',
#  'unfortunately little love with cuteness',
#  'sure which worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'sure which worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'sure which worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'sure which worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'which worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'worse poor acting ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'poor acting',
#  'poor acting',
#  'ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'ensemble cast flat dialogue Vincent Nebrida gutless direction Laurice Guillen',
#  'Goldmember none visual previous pictures looks though Roach directed film from back taxicab',
#  'though Roach directed film from back taxicab',
#  'directed film from back taxicab',
#  'point nausea',
#  'point nausea',
#  'about convincing other Arnie musclefest little much resonance with real world events ultimately comes insultingly simplistic',
#  'ultimately comes insultingly simplistic',
#  'unbelievably stupid film',
#  'unbelievably stupid',
#  'this crude',
#  'this crude',
#  'This movie sucks',
#  'sucks',
#  'sucks',
#  'sucks',
#  'donetodeath material',
#  'After that becomes long tedious like classroom play college history course',
#  'becomes long tedious like classroom play college history course',
#  'becomes long tedious like classroom play college history course',
#  'long tedious',
#  'While story betterfocused than incomprehensible Anne Rice novel based upon Queen Damned pointless meandering celebration gothvampire tortured woeisme lifestyle',
#  'Queen Damned pointless meandering celebration gothvampire tortured woeisme lifestyle',
#  'Damned pointless meandering celebration gothvampire tortured woeisme lifestyle',
#  'pointless meandering celebration gothvampire tortured woeisme lifestyle',
#  'pointless meandering',
#  'tortured',
#  'boring',
#  'movie dragged thought heard mysterious voice felt myself powerfully drawn toward light light exit sign',
#  'thought heard mysterious voice felt myself powerfully drawn toward light light exit sign',
#  'thought heard mysterious voice felt myself powerfully drawn toward light light exit sign',
#  'thought heard mysterious voice felt myself powerfully drawn toward light light exit sign',
#  'felt myself powerfully drawn toward light light exit sign',
#  'myself powerfully drawn toward light light exit sign',
#  'drawn toward light light exit sign',
#  'wreaked',
#  'seriously compromised that',
#  'frustration',
#  'flawed rather unexceptional',
#  'unexceptional',
#  'most excruciating minutes',
#  'most excruciating minutes',
#  'most excruciating',
#  'excruciating',
#  'involve dentist drill',
#  'sobadthey',
#  'this jumbled mess',
#  'this jumbled mess',
#  'started wonder some unpaid intern just typed Chris Rock Anthony Hopkins terrorists into some Univaclike script machine',
#  'some unpaid intern just typed Chris Rock Anthony Hopkins terrorists into some Univaclike script machine',
#  'just unlikable',
#  'unlikable',
#  'next thing notsobig notsohot',
#  'Overly long',
#  'remember last time movie where wanted badly protagonist fail',
#  'last time movie where wanted badly protagonist fail',
#  'undermining movie reality stifling creator comic voice',
#  'Limps along squirminducing fishoutofwater formula that goes nowhere goes there very very slowly',
#  'squirminducing fishoutofwater formula that goes nowhere goes there very very slowly',
#  'squirminducing fishoutofwater formula that goes nowhere goes there very very slowly',
#  'squirminducing fishoutofwater formula',
#  'that goes nowhere goes there very very slowly',
#  'goes nowhere goes there very very slowly',
#  'mechanical actioncomedy whose seeming purpose market charismatic Jackie Chan even younger audiences',
#  'Chalk worst kind hubristic folly',
#  'worst kind hubristic folly',
#  'worst kind hubristic folly',
#  'worst kind',
#  'worst',
#  'stomps hobnail boots over Natalie Babbitt gentle endearing 1975 children novel',
#  'served with hack script',
#  'insultingly inept artificial examination grief impacts upon relationships survivors',
#  'insultingly inept artificial examination grief impacts upon relationships survivors',
#  'insultingly inept artificial examination grief',
#  'insultingly inept artificial examination grief',
#  'insultingly inept artificial examination',
#  'insultingly inept artificial',
#  'tired unnecessary retread stale copy picture that that great begin with',
#  'tired unnecessary retread stale copy picture that that great begin with',
#  'tired unnecessary retread',
#  'tired unnecessary retread',
#  'picture that that great begin with',
#  'could pick lint Borg Queen Alice Krige cape',
#  'just rather leaden dull',
#  'leaden dull',
#  'never clearly defines characters gives reason care about them',
#  'crematorium chimney fires stacks dead bodies',
#  'which stagy',
#  'offers nonetoooriginal premise that everyone involved with moviemaking artist liar',
#  'maybe will feel after 88minute ripoff Rock with action confined slomo firing random glassshattering',
#  'maybe will feel after 88minute ripoff Rock with action confined slomo firing random glassshattering',
#  'will feel after 88minute ripoff Rock with action confined slomo firing random glassshattering',
#  'will feel after 88minute ripoff Rock with action confined slomo firing random glassshattering',
#  'will feel after 88minute ripoff Rock with action confined slomo firing random glassshattering',
#  'after 88minute ripoff Rock',
#  '88minute ripoff Rock',
#  '88minute ripoff',
#  '88minute ripoff',
#  'such cold movie claim express warmth longing',
#  'Shankman screenwriter Karen Janszen bungle their through narrative were series Bible parables actual story',
#  'bungle their through narrative were series Bible parables actual story',
#  'bungle their through narrative were series Bible parables actual story',
#  'terrible movie every regard utterly painful watch',
#  'terrible movie every regard utterly painful watch',
#  'terrible movie every regard utterly painful watch',
#  'terrible movie every regard',
#  'terrible movie every regard',
#  'terrible movie every regard',
#  'terrible movie every regard',
#  'terrible movie',
#  'utterly painful watch',
#  'spend same stuff buck that greasy little vidgame theater lobby',
#  'spend same stuff buck that greasy little vidgame theater lobby',
#  'spend same stuff buck that greasy little vidgame theater lobby',
#  'Wiel desperate attempt',
#  'lost leaving character Critical twodimensional pointless',
#  'Critical twodimensional pointless',
#  'other words badder than',
#  'badder than',
#  'badder than',
#  'badder than',
#  'badder than',
#  'Wedding feels anachronistic',
#  'other than fling gags',
#  'boring that even target audience talked through',
#  'boring',
#  'talked through',
#  'Rarely screen been aggressively antierotic',
#  'alienate mainstream audience while ringing cliched hardened indieheads',
#  'petty thievery like this that puts flimsy flicks like this behind bars',
#  'petty thievery like this that puts flimsy flicks like this behind bars',
#  'puts flimsy flicks like this behind bars',
#  'Nearly every attempt humor here',
#  'bland',
#  'Longley film lacks balance fails struggle into meaningful historical context',
#  'lacks balance fails struggle into meaningful historical context',
#  'contrived plotting stereotyped characters overthetop instincts director undermine moral dilemma movie heart',
#  'contrived plotting stereotyped characters',
#  'Even hardened voyeur would require patience through this interminable shapeless documentary about swinging subculture',
#  'require patience through this interminable shapeless documentary about swinging subculture',
#  'through this interminable shapeless documentary about swinging subculture',
#  'through this interminable shapeless documentary about swinging subculture',
#  'interminable shapeless documentary',
#  'practically hear George Orwell turning over',
#  'unrepentantly trashy',
#  'Pretend like your scores below might notice flaws',
#  'Pretend like your scores below',
#  'Pretend like your scores below',
#  'failed',
#  'definitely made kids their parents that matter think even fans Sandler comic taste find uninteresting',
#  'think even fans Sandler comic taste find uninteresting',
#  'find uninteresting',
#  'guess cast crew sign pact burn negative script pretend whole thing never existed',
#  'guess cast crew sign pact burn negative script pretend whole thing never existed',
#  'guess cast crew sign pact burn negative script pretend whole thing never existed',
#  'guess cast crew sign pact burn negative script pretend whole thing never existed',
#  'cast crew sign pact burn negative script pretend whole thing never existed',
#  'sign pact burn negative script pretend whole thing never existed',
#  'sign pact burn negative script pretend whole thing never existed',
#  'pact burn negative script pretend whole thing never existed',
#  'pact burn negative script pretend whole thing never existed',
#  'burn negative script pretend whole thing never existed',
#  'burn negative script pretend whole thing never existed',
#  'burn negative script',
#  'burn negative script',
#  'pretend whole thing never existed',
#  'something else altogether clownish offensive nothing like real life',
#  'something else altogether clownish offensive nothing like real life',
#  'something else altogether clownish offensive nothing like real life',
#  'offensive nothing like real life',
#  'tiresome love triangles',
#  'lack depth complexity',
#  'zeal squeeze action emotions into alltoofamiliar dramatic Holocaust escape story Minac drains movie individuality',
#  'squeeze action emotions into alltoofamiliar dramatic Holocaust escape story',
#  'Minac drains movie individuality',
#  'scream budget',
#  'muddled limp biscuit movie vampire soap opera that does make much sense even terms',
#  'muddled limp biscuit movie vampire soap opera that does make much',
#  'muddled limp biscuit',
#  'achieves remarkable feat squandering topnotch foursome actors',
#  'whitetrash',
#  'starts promisingly then proceeds flop',
#  'runs steam after half hour',
#  'knock back beer with they simply funny performers',
#  'simply funny performers',
#  'motion picture utterly static picture',
#  'motion picture utterly static picture',
#  'More same garbage Hollywood been trying pass acceptable teen entertainment some time',
#  'More same garbage',
#  'same garbage',
#  'same garbage',
#  'same garbage',
#  'garbage',
#  'Kitschy flashy overlong soap opera',
#  'developed characters much caricatures onedimensional buffoons that laughs nothing else',
#  'Execrable',
#  'Execrable',
#  'there nothing very attractive about this movie',
#  'nothing very attractive about this movie',
#  'unacceptable',
#  'unacceptable',
#  'frustrating patchwork uneasy marriage Louis Begley source novel About Schmidt Payne screenplay',
#  'frustrating patchwork',
#  'frustrating',
#  'like year late tapping into reality obsession even tardier exploiting novelty webcast',
#  'like year late tapping into reality obsession even tardier exploiting novelty webcast',
#  'tapping into reality obsession even tardier',
#  'been held hostage generic scripts that seek remake Sleepless Seattle again again',
#  'generic scripts that seek remake Sleepless Seattle again again',
#  'payoff audience well characters messy murky unsatisfying',
#  'messy murky unsatisfying',
#  'messy murky unsatisfying',
#  'messy murky unsatisfying',
#  'messy murky',
#  'messy murky',
#  'unsatisfying',
#  'intelligence audiences been grossly underestimated meaty plot welldeveloped characters have been sacrificed skin flash that barely fizzle',
#  'intelligence audiences been grossly underestimated meaty plot welldeveloped characters have been sacrificed skin flash that barely fizzle',
#  'took three minutes dialogue seconds plot turned them into 90minute movie that feels five hours long',
#  'took three minutes dialogue seconds plot turned them into 90minute movie that feels five hours long',
#  'took three minutes dialogue seconds plot turned them into 90minute movie that feels five hours long',
#  'dialogue seconds plot',
#  'turned them into 90minute movie that feels five hours long',
#  'into 90minute movie that feels five hours long',
#  'Interminably bleak nothing boring',
#  'Interminably bleak',
#  'This movie about worst thing Chan done United States',
#  'about worst thing Chan done United States',
#  'worst thing',
#  'worst thing',
#  'slack complacency',
#  'drown tinny selfrighteousness voice',
#  'disappointing meandering',
#  'action scenes that things fall apart',
#  'There palpable chemistry between Lopez male lead Ralph Fiennes plus script Working Girl scribe Kevin Wade workmanlike extreme',
#  'palpable chemistry between Lopez male lead Ralph Fiennes',
#  'limp comedy seen while meander through wornout material',
#  'limp comedy seen while meander through wornout material',
#  'limp comedy seen while meander through wornout material',
#  'both sitcomishly predictable cloying',
#  'crude film',
#  'mess',
#  'work that lacks both purpose strong pulse',
#  'Roses trailertrash style',
#  'trailertrash style',
#  'trailertrash style',
#  'fifty pileup cliches',
#  'fifty pileup cliches',
#  'pitiful slapdash disaster',
#  'pitiful slapdash disaster',
#  'slapdash disaster',
#  'slapdash disaster',
#  'disaster',
#  'erotic thriller that neither erotic very thrilling either',
#  'neither erotic very thrilling either',
#  'Irwin director never come with adequate reason should money what television free',
#  'standardissue crime drama spat from Tinseltown assembly line',
#  'Abandon will leave wanting abandon theater',
#  'Abandon will leave wanting abandon theater',
#  'will leave wanting abandon theater',
#  'will leave wanting abandon theater',
#  'leave wanting abandon theater',
#  'Before long desperate evening',
#  'desperate evening',
#  'Feels more like rejected XFiles episode than credible account puzzling reallife happening',
#  'rejected XFiles episode than credible account puzzling reallife happening',
#  'amount good intentions able overcome triviality story',
#  'deadend distaste',
#  'Distances throwing many herrings many false scares that genuine ones barely register',
#  'Every sequel skip will hours gained',
#  'Lots effort intelligence display execution awkward static lifeless rumblings',
#  'execution awkward static lifeless rumblings',
#  'awkward static lifeless rumblings',
#  'Consider film celluloid litmus test intellectual emotional pedigree your date giant step backward director admire',
#  'film celluloid litmus test intellectual emotional pedigree your date giant step backward director admire',
#  'giant step backward director admire',
#  'giant step backward',
#  'some contrived banter cliches some loose ends',
#  'same thing tired setting',
#  'pathetically compare notes about their budding amours',
#  'uncomfortable movie suffocating sometimes almost senseless Grey Zone does have center though morbid',
#  'uncomfortable movie suffocating sometimes almost senseless Grey Zone',
#  'uncomfortable movie suffocating sometimes almost senseless',
#  'uncomfortable movie suffocating sometimes almost senseless',
#  'uncomfortable movie',
#  'uncomfortable movie',
#  'suffocating sometimes almost senseless',
#  'morbid',
#  'lousy John',
#  'lousy',
#  'devoid pleasure sensuality that even dubbed hedonistic',
#  'devoid pleasure sensuality',
#  'Their contrast neither dramatic comic',
#  'Collateral Damage trash earns extra points acting were',
#  'Collateral Damage trash',
#  'Collateral Damage trash',
#  'trash',
#  'skinny Jerry Bruckheimer putrid pond retread action twaddle',
#  'Jerry Bruckheimer putrid pond retread action twaddle',
#  'good intentions leads video store',
#  'bile',
#  'sanctimonious selfrighteous eager earn love that want slap',
#  'have worn threadbare',
#  'perhaps effective creating atmosphere dustcaked stagnation labored gentility',
#  'finally succeeds diminishing stature from Oscarwinning master lowly studio hack',
#  'succeeds diminishing stature from Oscarwinning master lowly studio hack',
#  'succeeds diminishing stature from Oscarwinning master lowly studio hack',
#  'diminishing stature from Oscarwinning master lowly studio hack',
#  'Horrid little propaganda film',
#  'nearly dreadful expected',
#  'nearly dreadful',
#  'whole heap nothing core this slight comingofagecomingout tale',
#  'whole heap nothing core this slight comingofagecomingout tale',
#  'whole heap nothing core this slight comingofagecomingout tale',
#  'probably easy make such worthless film',
#  'probably easy make such worthless film',
#  'probably easy make such worthless film',
#  'easy make such worthless film',
#  'such worthless film',
#  'worthless film',
#  'worthless',
#  'drowns',
#  'film would total washout',
#  'might have been saved director spliced together bits pieces Midnight Hours that matter Shrek',
#  'dimwitted pairing teenspeak animal gibberish',
#  'What might have emerged hilarious lunacy hands Woody Allen Brooks least during their heyday comes across lame sophomoric this debut indie feature',
#  'comes across lame sophomoric this debut indie feature',
#  'comes across lame sophomoric',
#  'lame sophomoric',
#  'lame',
#  'have been this disappointed movie long time',
#  'have been this disappointed movie long time',
#  'have been this disappointed movie long time',
#  'been this disappointed movie long time',
#  'this disappointed movie long time',
#  'There comedic moment this romantic comedy',
#  'comedic moment this romantic comedy',
#  'comedic moment this romantic comedy',
#  'incredibly irritating comedy about thoroughly vacuous people manages embody worst excesses nouvelle vague without sense energy',
#  'incredibly irritating comedy about thoroughly vacuous people',
#  'incredibly irritating comedy',
#  'incredibly irritating comedy',
#  'embody worst excesses nouvelle vague without sense energy',
#  'None this very original particularly funny',
#  'None this very original',
#  'None this very original',
#  'devoid humor',
#  'thin writing proves undoing',
#  'Done mostly weak script that support epic treatment',
#  'weak script',
#  'hard believe that something short could flabby',
#  'indulges worst elements them',
#  'that true story which Queen allegedly inspired funnier more deftly enacted than what been cobbled together onscreen',
#  'which Queen allegedly inspired funnier more deftly enacted than what been cobbled together onscreen',
#  'conundrum worth solving',
#  'illness',
#  'Highly uneven inconsistent Margarita Happy Hour kinda resembles cheapo margaritas served within',
#  'Highly uneven inconsistent',
#  'Highly uneven inconsistent',
#  'tries touch spousal abuse veers course',
#  'Cagney world been replaced bottom barrel',
#  'Cagney world been replaced bottom barrel',
#  'been replaced bottom barrel',
#  'been replaced bottom barrel',
#  'bottom barrel',
#  'hardtoswallow premise',
#  'minority report that stinks',
#  'that stinks',
#  'stinks',
#  'Unless there zoning ordinances protect your community from dullest science fiction',
#  'zoning ordinances protect your community from dullest science fiction',
#  'from dullest science fiction',
#  'dullest science fiction',
#  'unfulfilling',
#  'only film Sopranos gags incredibly dated unfunny they also demonstrate desperate makers this doingitfor thecash sequel were',
#  'incredibly dated unfunny',
#  'dated unfunny',
#  'they also demonstrate desperate makers this doingitfor thecash sequel were',
#  'also demonstrate desperate makers this doingitfor thecash sequel were',
#  'demonstrate desperate makers this doingitfor thecash sequel were',
#  'makers this doingitfor thecash sequel were',
#  'makers this doingitfor thecash sequel',
#  'this doingitfor thecash sequel',
#  'bore',
#  'There real reason',
#  'There real reason',
#  'real reason',
#  'Master Disguise runs only minutes feels like three hours',
#  'runs only minutes feels like three hours',
#  'hate Crimen Padre Amaro because antiCatholic',
#  'Bears even worse than imagined movie ever could',
#  'even worse than imagined movie ever could',
#  'even worse than imagined movie ever could',
#  'Crush could worst film made about women since Valley Dolls',
#  'could worst film made about women since Valley Dolls',
#  'could worst film made about women since Valley Dolls',
#  'worst film made about women since Valley Dolls',
#  'worst film made about women since Valley Dolls',
#  'worst film',
#  'worst film',
#  'there enough intelligence innovation screen attract sustain older crowd',
#  'there enough intelligence innovation screen attract sustain older crowd',
#  'does offer audiences gripping what point even attitude toward subject',
#  'predictable tides',
#  'story Ghost Ship pretty landbound with leaden acting dull exposition telegraphed surprises',
#  'Ghost Ship pretty landbound with leaden acting dull exposition telegraphed surprises',
#  'face film subzero version Monsters without latter imagination visual charm texture',
#  'film subzero version Monsters without latter imagination visual charm texture',
#  'film subzero version Monsters without latter imagination visual charm texture',
#  'subzero version Monsters without latter imagination visual charm texture',
#  'subzero version Monsters without latter imagination',
#  'subzero version Monsters without latter imagination',
#  'negativity',
#  'Smug artificial illconstructed fatally overlong never finds consistent tone lacks bite degenerating into pious preachy soap opera',
#  'Smug artificial illconstructed fatally overlong',
#  'artificial illconstructed fatally overlong',
#  'illconstructed fatally overlong',
#  'illconstructed',
#  'fatally overlong',
#  'never finds consistent tone lacks bite degenerating into pious preachy soap opera',
#  'never finds consistent tone lacks bite degenerating into pious preachy soap opera',
#  'degenerating into pious preachy soap opera',
#  'pious preachy soap opera',
#  'gets girl loses girl audience falls asleep',
#  'gets girl loses girl audience falls asleep',
#  'audience falls asleep',
#  'nonstop artifice ultimately proves tiresome with surface histrionics failing compensate paperthin characterizations facile situations',
#  'ultimately proves tiresome with surface histrionics failing compensate paperthin characterizations facile situations',
#  'proves tiresome with surface histrionics failing compensate paperthin characterizations facile situations',
#  'proves tiresome with surface histrionics failing compensate paperthin characterizations facile situations',
#  'with surface histrionics failing compensate paperthin characterizations facile situations',
#  'there group more selfabsorbed women than mother daughters featured this film',
#  'will sleep bewildered artsy often pointless visuals',
#  'sleep bewildered artsy often pointless visuals',
#  'sleep bewildered artsy often pointless visuals',
#  'artsy often pointless',
#  'What ultimately makes Windtalkers disappointment superficial deals with story',
#  'disappointment superficial deals with story',
#  'disappointment',
#  'disappointment',
#  'Instead only sleep',
#  'only sleep',
#  'only sleep',
#  'only sleep',
#  'only sleep',
#  'Truly terrible',
#  'Truly terrible',
#  'Serving Sara much more serve than silly fluff',
#  'Serving Sara much more serve than silly fluff',
#  'much more serve than silly fluff',
#  'Watchable until point where situations dialogue spin hopelessly control that when Carol Kane appears screen',
#  'Watchable until point where situations dialogue spin hopelessly control that',
#  'situations dialogue spin hopelessly control that',
#  'some sort credible genderprovoking philosophy submerged here hell cares',
#  'Hopkins does much phone performance',
#  'Hopkins does much phone performance',
#  'confusing melange tones styles',
#  'documentary much conventional lots boring talking heads subject matter justice',
#  'lots boring talking heads',
#  'boring talking heads',
#  'most plain unimaginative romantic comedies',
#  'most plain unimaginative romantic comedies',
#  'unimaginative',
#  'unendurable viewing experience',
#  'unendurable viewing experience',
#  'unendurable',
#  'mostly fool gold',
#  'like madeforhomevideo quickie',
#  'madeforhomevideo quickie',
#  'especially thin stretched over nearly 80minute running time',
#  'continues systematically destroy everything hold dear about cinema only begun split that even more damage',
#  'continues systematically destroy everything hold dear about cinema only begun split that even more damage',
#  'systematically destroy everything hold dear about cinema only begun split that even more damage',
#  'systematically destroy everything hold dear about cinema only begun split that even more damage',
#  'sign thriller when instantly know whodunit',
#  'sign thriller when instantly know whodunit',
#  'Press delete',
#  'plot paperthin characters interesting enough watch them about their daily activities whole hours',
#  'plot paperthin characters interesting enough watch them about their daily activities whole hours',
#  'characters interesting enough watch them about their daily activities whole hours',
#  'interesting enough watch them about their daily activities whole hours',
#  'leaves shooting blanks',
#  'argue with anyone calls Slackers dumb insulting childish',
#  'surprisingly flat retread hobbled halfbaked setups sluggish pacing',
#  'retread hobbled halfbaked setups sluggish pacing',
#  'halfbaked setups sluggish pacing',
#  'halfbaked setups',
#  'hard understand anyone right mind would even think make attraction movie',
#  'hard understand anyone right mind would even think make attraction movie',
#  'hard understand anyone right mind would even think make attraction movie',
#  'hard understand anyone right mind would even think make attraction movie',
#  'anyone right mind would even think make attraction movie',
#  'Like Rudy Yellow Lodge Eyre needs take good sweat clarify cinematic vision before next creation remember lessons trickster spider',
#  'Eyre needs take good sweat clarify cinematic vision before next creation remember lessons trickster spider',
#  'Kids looks were made highly gifted 12yearold instead grown',
#  'leads unmemorable despite several attempts lengthy dialogue scenes that eventually resents having inhale this gutter romancer secondhand material',
#  'unmemorable despite several attempts lengthy dialogue scenes that eventually resents having inhale this gutter romancer secondhand material',
#  'unmemorable despite several attempts lengthy dialogue scenes that eventually resents having inhale this gutter romancer secondhand material',
#  'unmemorable despite several attempts lengthy dialogue scenes',
#  'unmemorable',
#  'eventually resents having inhale this gutter romancer secondhand material',
#  'having inhale this gutter romancer secondhand material',
#  'inhale this gutter romancer secondhand material',
#  'secondhand material',
#  'handles nuclear crisis sequences evenly milks drama when should building suspense drags many scenes toward that should move quickly',
#  'lika accents good',
#  'pedestrian that most positive comment make that Schneider actually turns pretty convincing performance prissy teenage girl',
#  'bother',
#  'like lint navel',
#  'flick that scalds like acid',
#  'that scalds like acid',
#  'soso madeforTV something posing real movie',
#  'posing real movie',
#  'crass insulting homage great films like Some Like John Wayne classics',
#  'crass insulting homage great films',
#  'crass insulting homage',
#  'This movie certain scene particular brought uncomfortably close losing lunch',
#  'brought uncomfortably close losing lunch',
#  'brought uncomfortably close losing lunch',
#  'close losing lunch',
#  'losing lunch',
#  'losing lunch',
#  'heavy stench been there done that hanging over film',
#  'Plodding poorly written murky weakly acted picture feels everyone making lost their movie mojo',
#  'poorly written murky weakly acted picture feels everyone making lost their movie mojo',
#  'poorly written murky weakly acted',
#  'picture feels everyone making lost their movie mojo',
#  'feels everyone making lost their movie mojo',
#  'script assumes that only would subtlety lost target audience that also stupid realize that they already seen this exact same movie hundred times',
#  'assumes that only would subtlety lost target audience that also stupid realize that they already seen this exact same movie hundred times',
#  'that only would subtlety lost target audience that also stupid realize that they already seen this exact same movie hundred times',
#  'that also stupid realize that they already seen this exact same movie hundred times',
#  'also stupid realize that they already seen this exact same movie hundred times',
#  'also stupid realize that they already seen this exact same movie hundred times',
#  'stupid',
#  'realize that they already seen this exact same movie hundred times',
#  'already seen this exact same movie hundred times',
#  'LaBute avoid fatal mistake modern',
#  'might want take reality check before full ticket price Simone consider rental instead',
#  'take reality check before full ticket price Simone consider rental instead',
#  'problem that that allows churn mediocre movie after another',
#  'that that allows churn mediocre movie after another',
#  'churn mediocre movie after another',
#  'churn mediocre movie after another',
#  'churn mediocre movie',
#  'recycled aspects implausibility sags pace',
#  'recycled aspects implausibility sags pace',
#  'recycled aspects implausibility',
#  'padded Allen jelly belly',
#  'astonishingly witless script',
#  'becomes more more frustrating film goes',
#  'becomes more more frustrating film goes',
#  'There cheesy backdrops ridiculous action sequences many tired jokes about heels',
#  'cheesy backdrops ridiculous action sequences many tired jokes about heels',
#  ...]

# %%
neg_total_words = ' '.join(neg_text_list)
neg_total_words = word_tokenize(neg_total_words)

neg_frequency = FreqDist(neg_total_words)

# %%
top_20_neg = px.bar(pd.DataFrame(neg_frequency, index=[0]).T.sort_values(by=[0], ascending=False).head(20))
top_20_neg.show()
# Out:
# <div>                            <div id="e022b2fa-5f0f-4140-bf5e-cf8e8d10b04f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e022b2fa-5f0f-4140-bf5e-cf8e8d10b04f")) {                    Plotly.newPlot(                        "e022b2fa-5f0f-4140-bf5e-cf8e8d10b04f",                        [{"alignmentgroup":"True","hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["that","movie","this","film","with","like","than","from","have","about","more","just","your","into","characters","minutes","comedy","even","worst","story"],"xaxis":"x","y":[1130,757,576,477,437,311,308,264,245,243,233,206,196,178,167,161,161,156,145,145],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":" ...

# %% [markdown]
# ### 긍정적인 감성에 자주 사용된 단어

# %%
pos_text_list = []
for idx, row in train[train['sentiment_class']=='positive'].iterrows():
    pos_text_list.append(row['Phrase'])

pos_text_list
# Out:
# ['This quiet introspective entertaining independent worth seeking',
#  'quiet introspective entertaining independent',
#  'entertaining',
#  'worth seeking',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder Shakespearean tragedy juicy soap opera',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder',
#  'thrilling',
#  'comedydrama nearly epic proportions rooted sincere performance title character undergoing midlife crisis',
#  'nearly epic',
#  'rooted sincere performance title character undergoing midlife crisis',
#  'sincere performance',
#  'sincere performance',
#  'sincere performance',
#  'recommend Snow Dogs',
#  'high hilarity',
#  'performances absolute',
#  'absolute',
#  'absolute',
#  'extravagant',
#  'better',
#  'this sweet modest ultimately winning story',
#  'sweet modest ultimately winning story',
#  'sweet modest',
#  'sweet',
#  'ultimately winning story',
#  'dizzily gorgeous',
#  'Love very much',
#  'Love',
#  'Best indie year',
#  'Best',
#  'indie year',
#  'impeccable',
#  'wellconstructed narrative',
#  'first computergenerated feature cartoon feel like other movies',
#  'runaway success first film Full Monty',
#  'runaway success',
#  'amusing',
#  'young romantics',
#  'horror movie primary goal frighten disturb then They works spectacularly well shiverinducing nerverattling ride',
#  'then They works spectacularly well shiverinducing nerverattling ride',
#  'then They works spectacularly well shiverinducing nerverattling ride',
#  'They works spectacularly well shiverinducing nerverattling ride',
#  'works spectacularly well shiverinducing nerverattling ride',
#  'works spectacularly well shiverinducing nerverattling ride',
#  'spectacularly well',
#  'spectacularly',
#  'sensational truecrime helljaunt purists might like more experimental storytelling though less horrifying',
#  'sensational truecrime',
#  'sensational',
#  'satisfying',
#  'Jones tackled meaty subject drawn engaging characters while peppering pages with memorable zingers',
#  'tackled meaty subject drawn engaging characters while peppering pages with memorable zingers',
#  'tackled meaty subject drawn engaging characters while peppering pages with memorable zingers',
#  'drawn engaging characters',
#  'engaging',
#  'memorable',
#  'Bloody Sunday grace call prevention rather than place blame making best movies ever made',
#  'grace call prevention rather than place blame making best movies ever made',
#  'grace call prevention rather than place blame making best movies ever made',
#  'grace call prevention rather than place blame making best movies ever made',
#  'grace call prevention rather than place blame making best movies ever made',
#  'call prevention rather than place blame making best movies ever made',
#  'call prevention rather than place blame making best movies ever made',
#  'making best movies ever made',
#  'best movies ever made',
#  'best movies ever made',
#  'best movies ever made',
#  'best movies ever made',
#  'best movies',
#  'Perhaps cliche call film refreshing',
#  'Perhaps cliche call film refreshing',
#  'refreshing',
#  'Both lead performances Oscarsize',
#  'smart comedy',
#  'smart comedy',
#  'smart',
#  'impressed',
#  'good',
#  'smart provocative drama that does nearly impossible gets under skin only know evil monstrous lunatic',
#  'smart provocative drama that does nearly impossible gets under skin only know evil monstrous lunatic',
#  'smart provocative drama that does nearly impossible',
#  'smart provocative drama that does nearly impossible',
#  'smart provocative drama',
#  'provocative drama',
#  'does nearly impossible',
#  'very funny',
#  'made movie that will leave wondering about characters lives after clever credits roll',
#  'made movie that will leave wondering about characters lives after clever credits roll',
#  'wondering about characters lives after clever credits roll',
#  'clever',
#  'This heartfelt story',
#  'heartfelt story',
#  'unsettling memorable cinematic experience that does predecessors proud',
#  'unsettling memorable cinematic experience that',
#  'memorable cinematic experience',
#  'does predecessors proud',
#  'proud',
#  'pretty good execution story that richer than ones Hollywood action screenwriters usually come with their',
#  'pretty good execution story that richer than ones Hollywood action screenwriters usually come with their',
#  'pretty',
#  'story that richer than ones Hollywood action screenwriters usually come with their',
#  'story that richer than ones Hollywood action screenwriters usually come with their',
#  'Inventive',
#  'sexy',
#  'Tells fascinating compelling story',
#  'fascinating compelling story',
#  'fascinating compelling story',
#  'Highly recommended viewing courage ideas technical proficiency great acting',
#  'recommended viewing courage ideas technical proficiency great acting',
#  'recommended',
#  'courage ideas technical proficiency great acting',
#  'courage ideas technical proficiency great acting',
#  'great acting',
#  'great',
#  'IMAX short just wonderful screen',
#  'just wonderful screen',
#  'wonderful screen',
#  'wonderful screen',
#  'enjoy',
#  'pleasure',
#  'Invigorating surreal resonant with rainbow emotion',
#  'Invigorating surreal resonant with rainbow emotion',
#  'Invigorating surreal resonant with rainbow',
#  'particularly good film',
#  'particularly good film',
#  'particularly good',
#  'surprisingly solid achievement',
#  'recent memory most thoughtful films about ethics cost moral compromise',
#  'most thoughtful films about ethics cost moral compromise',
#  'most thoughtful films about ethics cost moral compromise',
#  'thoughtful',
#  'Filmmaker Tian Zhuangzhuang triumphantly returns narrative filmmaking with visually masterful work quiet power',
#  'triumphantly returns narrative filmmaking with visually masterful work quiet power',
#  'returns narrative filmmaking with visually masterful work quiet power',
#  'returns narrative filmmaking with visually masterful work quiet power',
#  'narrative filmmaking with visually masterful work quiet power',
#  'filmmaking with visually masterful work quiet power',
#  'with visually masterful work quiet power',
#  'visually masterful work quiet power',
#  'visually masterful work',
#  'visually masterful work',
#  'visually masterful',
#  'masterful',
#  'Masterpiece',
#  'stirring visual sequence',
#  'leap from pinnacle pinnacle',
#  'delivers perfect performance that captures innocence budding demons within wallflower',
#  'delivers perfect performance that captures innocence budding demons within wallflower',
#  'perfect performance that captures innocence budding demons within wallflower',
#  'perfect performance',
#  'perfect performance',
#  'perfect',
#  'years Russian history culture compressed into evanescent seamless sumptuous stream consciousness',
#  'evanescent seamless sumptuous stream consciousness',
#  'filmmakers want nothing else than show good time',
#  'Polanski element here',
#  'element',
#  'Spiderman better than summer blockbuster endure last summer hopefully sets tone summer good stuff',
#  'Spiderman better than summer blockbuster endure last summer hopefully sets tone summer good stuff',
#  'better than summer blockbuster endure last summer hopefully sets tone summer good stuff',
#  'better than summer blockbuster endure last summer hopefully sets tone summer good stuff',
#  'better than summer blockbuster',
#  'better than summer blockbuster',
#  'hopefully sets tone summer good stuff',
#  'prove more potent riveting than unlikely story Sarah Harrison',
#  'potent riveting',
#  'riveting',
#  'Winds being both revelatory narcissistic achieving some honest insight into relationships that most highconcept films candycoat with storylines precious circumstances beautiful stars',
#  'honest',
#  'storylines precious circumstances beautiful stars',
#  'beautiful',
#  'still sweet even delectable diversion',
#  'still sweet even delectable diversion',
#  'sweet even delectable',
#  'delectable',
#  'thoughtful surprisingly affecting portrait screwedup dared mess with some powerful people seen through eyes idealistic chooses champion ultimately losing cause',
#  'thoughtful surprisingly affecting portrait screwedup dared mess with some powerful people seen through eyes idealistic chooses champion ultimately losing cause',
#  'thoughtful surprisingly affecting',
#  'powerful',
#  'brilliant',
#  'triumph film that hews world carries effortlessly from darkness light',
#  'triumph film that hews world carries effortlessly from darkness light',
#  'triumph',
#  'film that hews world carries effortlessly from darkness light',
#  'fascinating dark thriller that keeps',
#  'year most weirdly engaging unpredictable character pieces',
#  'Intriguing downright intoxicating',
#  'Intriguing downright intoxicating',
#  'downright intoxicating',
#  'fresh',
#  'Sleek arty',
#  'face amazing slapstick instrument',
#  'amazing slapstick',
#  'amazing slapstick',
#  'amazing',
#  'When cowering begging feet scruffy Giannini Madonna gives best performance since Abel Ferrara beaten pulp Dangerous Game',
#  'gives best performance since Abel Ferrara beaten pulp Dangerous Game',
#  'Spielberg realization nearfuture America masterful',
#  'masterful',
#  'masterful',
#  'film only love song movies also more fully example kind lush allenveloping movie experience rhapsodizes',
#  'film only love song movies also more fully example kind lush allenveloping movie experience rhapsodizes',
#  'film only love song movies also more fully example kind lush allenveloping movie experience rhapsodizes',
#  'also more fully example kind lush allenveloping movie experience rhapsodizes',
#  'example kind lush allenveloping movie experience',
#  'kind lush allenveloping movie experience',
#  'lush allenveloping movie experience',
#  'allenveloping movie experience',
#  'uncluttered resonant',
#  'resonant',
#  'perfectly entertaining summer diversion',
#  'perfectly',
#  'makes this rather convoluted journey worth taking',
#  'Steven Shainberg adaptation Mary Gaitskill harrowing short story brilliantly played deeply unsettling experience',
#  'brilliantly played deeply unsettling experience',
#  'brilliantly played deeply unsettling experience',
#  'brilliantly played',
#  'brilliantly',
#  'wellmade emotionally scattered film whose hero gives heart only',
#  'wellmade',
#  'wellmade',
#  'gets tone just right',
#  'just right',
#  'Charming funny ultimately silly movie',
#  'Charming',
#  'children film truest sense',
#  'Beautifully crafted engaging filmmaking that should attract upscale audiences hungry quality nostalgic twisty yarn that will keep them guessing',
#  'Beautifully',
#  'crafted engaging filmmaking that should attract upscale audiences hungry quality nostalgic twisty yarn that will keep them guessing',
#  'engaging filmmaking that should attract upscale audiences hungry quality nostalgic twisty yarn that will keep them guessing',
#  'filmmaking that should attract upscale audiences hungry quality nostalgic twisty yarn that will keep them guessing',
#  'should attract upscale audiences hungry quality nostalgic twisty yarn that will keep them guessing',
#  'quality nostalgic twisty yarn that will keep them guessing',
#  'film also imbued with strong themes familial ties spirituality that powerful moving without stooping base melodrama',
#  'with strong themes familial ties spirituality that powerful moving without stooping base melodrama',
#  'spirituality that powerful moving without stooping base melodrama',
#  'powerful moving without stooping base melodrama',
#  'powerful moving',
#  'Evokes style flash doublecross that made Mamet House Games last fall Heist much',
#  'style flash doublecross that made Mamet House Games last fall Heist much',
#  'doublecross that made Mamet House Games last fall Heist much',
#  'that made Mamet House Games last fall Heist much',
#  'Mamet House Games last fall Heist much',
#  'much',
#  'aims funny uplifting moving sometimes once',
#  'funny uplifting moving',
#  'uplifting moving',
#  'uplifting moving',
#  'disappointed',
#  'humor',
#  'This superior horror flick',
#  'superior horror flick',
#  'superior horror flick',
#  'superior horror flick',
#  'well told',
#  'More sophisticated literate than such pictures usually',
#  'literate',
#  'Monte Cristo smartly emphasizes wellwrought story omits needless chase scenes swordfights revenge unfolds',
#  'emphasizes wellwrought story omits needless chase scenes swordfights revenge unfolds',
#  'emphasizes wellwrought story omits needless chase scenes swordfights revenge unfolds',
#  'wellwrought story',
#  'wellwrought story',
#  'fairy tale that comes from renowned Indian film culture that allows Americans finally revel splendor',
#  'fairy tale that comes from renowned Indian film culture that allows Americans finally revel splendor',
#  'fairy tale that comes from renowned Indian film culture that allows Americans finally revel splendor',
#  'fairy tale that comes from renowned Indian film culture that allows Americans finally revel splendor',
#  'from renowned Indian film culture that allows Americans finally revel splendor',
#  'splendor',
#  'Welldone supernatural thriller with keen insights into parapsychological phenomena soulful nuances',
#  'Welldone supernatural thriller',
#  'When this rich luscious',
#  'terrific',
#  'sizzle news that finally found right vent accurate',
#  'strikes defiantly retro chord outpaces contemporaries with daring verve',
#  'strikes defiantly retro chord outpaces contemporaries with daring verve',
#  'riproaring comedy action',
#  'thoughtful whatif heart well mind',
#  'Miyazaki world cinema most wondrously gifted artists storytellers',
#  'world cinema most wondrously gifted artists storytellers',
#  'world cinema most wondrously gifted artists storytellers',
#  'world cinema most wondrously gifted artists',
#  'world cinema most wondrously gifted artists',
#  'world cinema most wondrously gifted artists',
#  'world cinema most wondrously gifted artists',
#  'most wondrously gifted artists',
#  'most wondrously',
#  'Provides kind laugh therapy need from movie comedies offbeat humor amusing characters happy ending',
#  'Provides kind laugh therapy need from movie comedies offbeat humor amusing characters happy ending',
#  'Provides kind laugh therapy need from movie comedies',
#  'Provides kind laugh therapy need from movie comedies',
#  'kind laugh therapy need from movie comedies',
#  'offbeat humor amusing characters happy ending',
#  'offbeat humor amusing characters',
#  'amusing characters',
#  'happy',
#  'Godfrey Reggio career shines like lonely beacon',
#  'shines',
#  'does many little things right',
#  'greatest triumph',
#  'greatest triumph',
#  'This movie have highest production values ever seen work artist whose view America history awkwardness human life generous deep',
#  'have highest production values ever seen',
#  'highest production values ever seen',
#  'highest production values',
#  'highest production values',
#  'work artist whose view America history awkwardness human life generous deep',
#  'generous deep',
#  'Sillier cuter shorter than first best remember still very good time cinema',
#  'very good time',
#  'very good time',
#  'predictable reassuring manner beautifully sung holiday carol',
#  'Offers flash rock videos fused with solid performances eerie atmosphere',
#  'fused with solid performances eerie atmosphere',
#  'fused with solid performances eerie atmosphere',
#  'with solid performances eerie atmosphere',
#  'increasingly diverse French director created film that honestly describe looking sounding simply feeling like other film recent history',
#  'increasingly diverse French director',
#  'honestly describe looking sounding simply feeling like other film recent history',
#  'feeling like other film recent history',
#  'joyous films that leaps over national boundaries celebrates universal human nature',
#  'joyous films that leaps over national boundaries celebrates universal human nature',
#  'films that leaps over national boundaries celebrates universal human nature',
#  'that leaps over national boundaries celebrates universal human nature',
#  'worthy',
#  'Witty often surprising dark little morality tale disguised romantic comedy',
#  'Thanks confident filmmaking pair fascinating performances that destination really special walk woods',
#  'Thanks confident filmmaking pair fascinating performances',
#  'confident filmmaking pair fascinating performances',
#  'confident',
#  'fascinating performances',
#  'really special walk',
#  'Superbly photographed staged Mendes with series riveting pieces likes which mainstream audiences have rarely seen',
#  'with series riveting pieces',
#  'mesmerizing cinematic poem from first frame last',
#  'mesmerizing cinematic poem from first frame last',
#  'mesmerizing cinematic poem',
#  'mesmerizing',
#  'which worth seeing',
#  'Screenwriter Chris Weil directing debut goodnatured never dull',
#  'goodnatured',
#  'brilliant',
#  'sharp original',
#  'smart arch rather coldblooded comedy',
#  'smart',
#  'inspires',
#  'Robinson suspense matches pageturning frenzy that Clancy creates',
#  'Austin Powers Goldmember right stuff silly summer entertainment enough laughs sustain interest',
#  'enough laughs sustain interest',
#  'While maintaining appearance clinical objectivity this occasionally horrifying often inspiring film among Wiseman warmest',
#  'this occasionally horrifying often inspiring film among Wiseman warmest',
#  'this occasionally horrifying often inspiring film',
#  'There simply doubt that this film asks right questions right time history country',
#  'simply doubt that this film asks right questions right time history country',
#  'this film asks right questions right time history country',
#  'injects just enough freshness into proceedings provide enjoyable minutes movie theater',
#  'enough freshness',
#  'provide enjoyable minutes movie theater',
#  'enjoyable minutes movie theater',
#  'begins conventional thriller evolves into gorgeously atmospheric meditation lifechanging chance encounters',
#  'director experiment successful',
#  'director experiment successful',
#  'successful',
#  'successful',
#  'Judith Zaza extended bedroom sequence intimate sensual funny psychologically selfrevealing that makes most what passes movies look like cheap hysterics',
#  'intimate sensual funny psychologically selfrevealing that makes most what passes movies look like cheap hysterics',
#  'intimate sensual funny psychologically selfrevealing that makes most what passes movies look like cheap hysterics',
#  'intimate sensual funny psychologically selfrevealing',
#  'intimate sensual funny',
#  'solid spooky entertainment worthy price ticket',
#  'solid spooky entertainment',
#  'worthy price ticket',
#  'Except much much better',
#  'happy heady jumble thought storytelling insane comic undertaking that ultimately coheres into sane breathtakingly creative film',
#  'happy heady jumble thought storytelling insane comic undertaking that ultimately coheres into sane breathtakingly creative film',
#  'happy heady jumble thought storytelling insane comic undertaking that ultimately coheres into sane breathtakingly creative film',
#  'happy heady jumble thought storytelling insane comic undertaking that ultimately coheres into sane breathtakingly creative film',
#  'happy heady jumble thought storytelling',
#  'happy heady jumble thought storytelling',
#  'insane comic undertaking that ultimately coheres into sane breathtakingly creative film',
#  'that ultimately coheres into sane breathtakingly creative film',
#  'coheres into sane breathtakingly creative film',
#  'into sane breathtakingly creative film',
#  'sane breathtakingly creative film',
#  'breathtakingly',
#  'creative',
#  'original base concept that help caught',
#  'original base concept that help caught',
#  'band performances featured Drumline',
#  'Leigh rare directors feels acting heart soul cinema',
#  'rare directors feels acting heart soul cinema',
#  'rare directors feels acting heart soul cinema',
#  'heart soul cinema',
#  'monumental achievement',
#  'monumental achievement',
#  'monumental achievement',
#  'monumental',
#  'Rock standup magic',
#  'With empathy spare',
#  'certainly raises film above anything Sandler been attached before',
#  'raises film above anything Sandler been attached before',
#  'film above anything Sandler been attached before',
#  'deeper more engaging',
#  'Those moviegoers would automatically bypass hiphop documentary should give Scratch second look',
#  'With without wonderful tale love destiny told well master storyteller',
#  'With without wonderful tale love destiny',
#  'wonderful tale love destiny',
#  'wonderful tale love destiny',
#  'wonderful tale',
#  'master',
#  'terrific date movie',
#  'laughter',
#  'funniest idea',
#  'funniest',
#  'Frailty offers chills much like those that when sitting around campfire around midnight telling creepy stories give each other willies',
#  'Frailty offers chills much like those that when sitting around campfire around midnight telling creepy stories give each other willies',
#  'offers chills much like those that when sitting around campfire around midnight telling creepy stories give each other willies',
#  'ambitious movie that like Shiner organizing fight pulls enough effects make ones that come',
#  'ambitious movie that like Shiner organizing fight pulls enough effects make ones that come',
#  'Some movies suck despite their flaws Heaven such beast',
#  'Very well written directed with brutal honesty respect audience',
#  'well written directed with brutal honesty respect audience',
#  'written directed with brutal honesty respect audience',
#  'written directed with brutal honesty respect audience',
#  'brutal honesty respect',
#  'Twenty years after first release remains most wondrous Hollywood fantasies apex Steven Spielberg misunderstood career',
#  'remains most wondrous Hollywood fantasies apex Steven Spielberg misunderstood career',
#  'remains most wondrous Hollywood fantasies apex Steven Spielberg misunderstood career',
#  'remains most wondrous Hollywood fantasies apex Steven Spielberg misunderstood career',
#  'most wondrous Hollywood fantasies apex Steven Spielberg misunderstood career',
#  'most wondrous Hollywood fantasies',
#  'combines enigmatic features Memento with hallucinatory drug culture Requiem Dream',
#  'Every individual will movie through prism beliefs prejudices thing most will take away sense that peace possible',
#  'Every individual will movie through prism beliefs prejudices thing most will take away sense that peace possible',
#  'Leguizamo Jones both excellent rest cast uniformly superb',
#  'Leguizamo Jones both excellent rest cast uniformly superb',
#  'Leguizamo Jones both excellent',
#  'Leguizamo Jones both excellent',
#  'both excellent',
#  'excellent',
#  'uniformly superb',
#  'uniformly superb',
#  'superb',
#  'interesting meditation',
#  'Delia Greta Paula rank three most multilayered sympathetic female characters year',
#  'rank three most multilayered sympathetic female characters year',
#  'rank three most multilayered sympathetic female characters year',
#  'most multilayered sympathetic female characters year',
#  'most multilayered sympathetic female characters',
#  'averse usually feelgood followyourdream Hollywood fantasies this',
#  'film wellcrafted this',
#  'film wellcrafted this',
#  'film wellcrafted',
#  'film wellcrafted',
#  'still able create engaging story that keeps guessing almost every turn',
#  'able create engaging story that keeps guessing almost every turn',
#  'create engaging story that keeps guessing almost every turn',
#  'create engaging story that keeps guessing almost every turn',
#  'engaging story that keeps guessing almost every turn',
#  'going recommend SECRETARY based wonderful acting clinic Spader Gyllenhaal',
#  'recommend SECRETARY based wonderful acting clinic Spader Gyllenhaal',
#  'based wonderful acting clinic Spader Gyllenhaal',
#  'wonderful acting clinic Spader Gyllenhaal',
#  'wonderful acting clinic Spader Gyllenhaal',
#  'also unique Shainberg goes about telling what heart sweet little girl',
#  'about telling what heart sweet little girl',
#  'heart sweet little girl',
#  'Barbershop goodhearted ensemble comedy with variety quirky characters engaging story',
#  'goodhearted ensemble comedy with variety quirky characters engaging story',
#  'goodhearted ensemble comedy with variety quirky characters engaging story',
#  'goodhearted ensemble comedy with variety quirky characters engaging story',
#  'goodhearted ensemble comedy',
#  'goodhearted ensemble comedy',
#  'with variety quirky characters engaging story',
#  'quirky characters engaging story',
#  'quirky characters engaging story',
#  'Consistently clever suspenseful',
#  'clever suspenseful',
#  'Hilarious musical comedy',
#  'Kouyate elicits strong performances from cast delivers powerful commentary governments matter runs them',
#  'elicits strong performances from cast',
#  'asylum material gripping scenes with family',
#  'gripping scenes with family',
#  'walked away from this version just hoped would with moist eyes',
#  'walked away from this version just hoped would with moist eyes',
#  'powerful though flawed movie guaranteed lump your throat while reaffirming Washington possibly best actor working movies today',
#  'powerful though flawed movie guaranteed lump your throat while reaffirming Washington possibly best actor working movies today',
#  'guaranteed lump your throat while reaffirming Washington possibly best actor working movies today',
#  'lump your throat while reaffirming Washington possibly best actor working movies today',
#  'lump your throat while reaffirming Washington possibly best actor working movies today',
#  'while reaffirming Washington possibly best actor working movies today',
#  'reaffirming Washington possibly best actor working movies today',
#  'Washington possibly best actor working movies today',
#  'possibly best actor working movies today',
#  'possibly best actor working movies today',
#  'possibly best actor',
#  'best actor',
#  'laughing',
#  'soulful gravity',
#  'Crudup anchoring performance',
#  'This beautifully animated epic never dull',
#  'This beautifully animated epic',
#  'beautifully animated epic',
#  'Charming witty',
#  'mostly admirable',
#  'admirable',
#  'decent sense humor plenty',
#  'sends away believer again quite cheered just that',
#  'sends away believer again quite cheered just that',
#  'most remarkable because epic scope because startling intimacy achieves despite that breadth',
#  'most remarkable because epic scope because startling intimacy achieves despite that breadth',
#  'most remarkable because epic scope because startling intimacy achieves despite that breadth',
#  'most remarkable',
#  'remarkable',
#  'because epic scope because startling intimacy',
#  'poignant',
#  'straightshooting family film which awards animals respect they rarely been given',
#  'honestly affecting',
#  'Home Alabama',
#  'this datenight diversion will definitely some hearts',
#  'affectionate delight',
#  'delight',
#  'film manages keep edge your seat with shapeshifting perils political intrigue brushes with calamity',
#  'manages keep edge your seat with shapeshifting perils political intrigue brushes with calamity',
#  'manages keep edge your seat with shapeshifting perils political intrigue brushes with calamity',
#  'keep edge your seat with shapeshifting perils political intrigue brushes with calamity',
#  'keep edge your seat with shapeshifting perils political intrigue brushes',
#  'edge your seat with shapeshifting perils political intrigue brushes',
#  'edge your seat with shapeshifting perils political intrigue brushes',
#  'Brings awareness issue often overlooked',
#  'Definitely funny stuff',
#  'laughing',
#  'hope',
#  'emotionally strong politically potent piece cinema',
#  'emotionally strong politically potent piece cinema',
#  'emotionally strong politically potent piece',
#  'hope movie widely seen debated with appropriate ferocity thoughtfulness',
#  'Intelligent moving',
#  'Intelligent moving',
#  'Intelligent',
#  'strong directorial stamp every frame this stylish film that able visualize schizophrenia still confident enough step back look sick character with sane',
#  'every frame this stylish film that able visualize schizophrenia still confident enough step back look sick character with sane',
#  'this stylish film that able visualize schizophrenia still confident enough step back look sick character with sane',
#  'Romantic riveting handsomely animated',
#  'Romantic riveting handsomely',
#  'Captures comic energy most flamboyant female comics',
#  'exceptionally acted quietly affecting drama',
#  'Perfectly pitched between comedy tragedy hope despair About Schmidt instead comes closer than many movies expressing many live someplace between consuming selfabsorption insistently demanding otherness',
#  'comes closer than many movies expressing many live someplace between consuming selfabsorption insistently demanding otherness',
#  'nearly glows with enthusiasm sensuality conniving',
#  'glows with enthusiasm sensuality conniving',
#  'with enthusiasm sensuality conniving',
#  'Strange funny twisted brilliant macabre',
#  'funny twisted brilliant macabre',
#  'twisted brilliant macabre',
#  'twisted brilliant macabre',
#  'brilliant macabre',
#  'brilliant',
#  'rocksolid gangster movie',
#  'rocksolid gangster movie',
#  'suspense intriguing characters bizarre bank robberies',
#  'suspense intriguing characters',
#  'suspense intriguing characters',
#  'JeanClaude Damme look good',
#  'essence magic makebelieve promise life that soars above material realm this opposite truly magical movie',
#  'makebelieve promise life that soars above material realm',
#  'soars',
#  'truly magical movie',
#  'truly magical movie',
#  'truly magical movie',
#  'truly magical',
#  'storytelling prowess special effects',
#  'stopped thinking about good started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'stopped thinking about good started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'thinking about good started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'about good started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'good started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'started doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'doing nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'grand',
#  'visual delights',
#  'visual delights',
#  'lovely trifle',
#  'purely enjoyable',
#  'intelligent multilayered profoundly humanist mention gently political meditation values knowledge education affects cultural geographical displacement',
#  'sexy peculiar always entertaining costume drama Renaissance Spain fact that based true events somehow makes more compelling',
#  'sexy peculiar always entertaining costume drama Renaissance Spain fact that based true events',
#  'sexy peculiar always entertaining costume drama',
#  'sexy peculiar always entertaining costume drama',
#  'peculiar always entertaining',
#  'always entertaining',
#  'makes more compelling',
#  'proves itself more streamlined thought encounter than original could ever have hoped',
#  'sweet laughaminute crowd pleaser that lifts your spirits well corners your mouth',
#  'sweet laughaminute crowd pleaser that lifts your spirits well corners your mouth',
#  'sweet laughaminute crowd pleaser that lifts your spirits well corners your mouth',
#  'sweet laughaminute crowd pleaser that lifts your spirits',
#  'laughaminute crowd pleaser',
#  'crowd pleaser',
#  'engrossing story about horrifying historical event elements which contributed',
#  'engrossing story',
#  'engrossing',
#  'hilarious dialogue',
#  'powerful sequel best films year',
#  'powerful sequel best films year',
#  'powerful sequel best films year',
#  'powerful sequel',
#  'powerful sequel',
#  'best films year',
#  'best films year',
#  'best films',
#  'Chabrol subtlest works also most uncanny',
#  'film constant mood melancholy unhurried narrative masterfully controlled',
#  'masterfully controlled',
#  'masterfully controlled',
#  'masterfully controlled',
#  'masterfully',
#  'movie that defies classification thoughtprovoking',
#  'movie moment gems',
#  'color sense Stuart Little most immediate most obvious pleasure would count very little movie were beautifully shaped delicately calibrated tone',
#  'would count very little movie were beautifully shaped delicately calibrated tone',
#  'beautifully shaped delicately calibrated tone',
#  'Treasure Planet rivals Japanese animations recent vintage',
#  'rivals Japanese animations recent vintage',
#  'which anyone relate',
#  'Peralta captures luminous interviews amazingly evocative film from three decades essence Dogtown experience',
#  'captures luminous interviews amazingly evocative film from three decades essence Dogtown experience',
#  'luminous interviews amazingly evocative film from three decades',
#  'luminous interviews amazingly evocative film from three decades',
#  'luminous interviews',
#  'luminous',
#  'amazingly evocative film',
#  'amazingly evocative',
#  'euphoria',
#  'Standing Shadows Motown best kind documentary that makes depleted yesterday feel very much like brandnew tomorrow',
#  'best kind documentary that makes depleted yesterday feel very much like brandnew tomorrow',
#  'best kind documentary that makes depleted yesterday feel very much like brandnew tomorrow',
#  'best kind',
#  'best kind',
#  'good actors good poetry good music',
#  'good actors good poetry',
#  'thriller whose style structure rhythms integrated with story',
#  'mostly pleasure watch',
#  'pleasure watch',
#  'rich tiny revelations real life',
#  'Goofy nutty consistently funny',
#  'consistently funny',
#  'consistently funny',
#  'Audiard successfully maintains suspense different levels throughout film that both gripping compelling',
#  'successfully maintains suspense different levels throughout film that both gripping compelling',
#  'throughout film that both gripping compelling',
#  'film that both gripping compelling',
#  'that both gripping compelling',
#  'good cinema',
#  'Mostly works because universal themes earnest performances excellent music India popular Gulzar Jagjit Singh',
#  'works because universal themes earnest performances excellent music India popular Gulzar Jagjit Singh',
#  'works because universal themes earnest performances excellent music India popular Gulzar Jagjit Singh',
#  'excellent music India popular Gulzar Jagjit Singh',
#  'perceptive goodnatured movie',
#  'stand cheer flick',
#  'wiser',
#  'great movie',
#  'great movie',
#  'refreshingly forthright',
#  'refreshingly forthright',
#  'rollicking adventure your mateys regardless their ages',
#  'rollicking adventure your mateys regardless their ages',
#  'rollicking adventure',
#  'content with clever pseudobio that manages have good time doles pieces famous director life',
#  'with clever pseudobio that manages have good time doles pieces famous director life',
#  'clever pseudobio',
#  'Eisenstein delivers',
#  'visual spectacle full stunning images effects',
#  'visual spectacle full stunning images effects',
#  'full stunning images effects',
#  'stunning images effects',
#  'stunning images effects',
#  'stunning',
#  'something that meditative lyrical about Babak Payami boldly quirky Iranian drama Secret Ballot charming evoking little ditty that manages show gentle humane side Middle Eastern world politics',
#  'something that meditative lyrical about Babak Payami boldly quirky Iranian drama Secret Ballot charming evoking little ditty that manages show gentle humane side Middle Eastern world politics',
#  'charming evoking little ditty',
#  'charming evoking',
#  'Westbrook foundation Dalrymple film earn their uplift',
#  'that truly enjoyed most Mostly Martha while',
#  'truly enjoyed most Mostly Martha while',
#  'early middle passages surprising much they engage even touch',
#  'surprising much they engage even touch',
#  'really funny fifteenminute',
#  'really funny',
#  'Writer director Otar Iosseliani pleasant tale about factory worker escapes holiday Venice reveals need playful respite from grind refresh souls',
#  'Writer director Otar Iosseliani pleasant tale about factory worker escapes holiday Venice',
#  'pleasant',
#  'playful',
#  'epic American story',
#  'actionpacked experience ringside seat toughman contest',
#  'immersive powers giant screen hyperrealistic images perfect breathtakingly beautiful outerspace documentary Space Station',
#  'immersive powers giant screen hyperrealistic images',
#  'hyperrealistic images',
#  'perfect breathtakingly beautiful outerspace documentary Space Station',
#  'perfect breathtakingly beautiful outerspace documentary Space Station',
#  'perfect breathtakingly beautiful outerspace documentary Space Station',
#  'perfect breathtakingly beautiful outerspace documentary Space Station',
#  'breathtakingly beautiful outerspace documentary Space Station',
#  'breathtakingly beautiful outerspace documentary Space Station',
#  'Muccino directed from screenplay canny crowd pleaser Last Kiss provides more than enough sentimental catharsis satisfying evening multiplex',
#  'canny crowd pleaser Last Kiss',
#  'canny crowd pleaser',
#  'canny crowd pleaser',
#  'provides more than enough sentimental catharsis satisfying evening multiplex',
#  'satisfying evening multiplex',
#  'Read Lips viewed treasured extraordinary intelligence originality well lyrical variations game love',
#  'viewed treasured extraordinary intelligence originality well lyrical variations game love',
#  'viewed treasured extraordinary intelligence originality well lyrical variations game love',
#  'viewed treasured extraordinary intelligence originality',
#  'extraordinary intelligence originality',
#  'extraordinary intelligence originality',
#  'extraordinary intelligence originality',
#  'extraordinary',
#  'hour half joyful solo performance',
#  'joyful solo performance',
#  'joyful',
#  'stereotypes good while adding heart unsettling subject matter',
#  'film works mostly superior cast characters',
#  'mostly superior cast',
#  'superior cast',
#  'superior cast',
#  'superior cast',
#  'vividly detailed story about newcomers strange world',
#  'inspirational',
#  'impressive images',
#  'impressive',
#  'There been string ensemble cast romances recently Peter Mattei Love Time Money sets itself apart forming chain relationships that come full circle positive tragic note',
#  'Peter Mattei Love Time Money sets itself apart forming chain relationships that come full circle positive tragic note',
#  'sets itself apart forming chain relationships that come full circle positive tragic note',
#  'positive tragic note',
#  'This popcorn movie with equal doses action cheese cheek well serious debt Road Warrior',
#  'popcorn movie',
#  'actress Madonna helluva singer',
#  'Madonna helluva singer',
#  'Madonna helluva singer',
#  'helluva singer',
#  'helluva singer',
#  'Enough pander basest desires payback unlike many revenge fantasies ultimately delivers',
#  'unlike many revenge fantasies ultimately delivers',
#  'ultimately delivers',
#  'warmth',
#  'vivid thoughtful unapologetically comingofage tale full drugs rock roll',
#  'vivid thoughtful unapologetically comingofage tale',
#  'vivid thoughtful unapologetically comingofage tale',
#  'bittersweet contemporary comedy about benevolent deception which while rival filmmaker period pieces still very much worth seeing',
#  'bittersweet contemporary comedy about benevolent deception which while rival filmmaker period pieces still very much worth seeing',
#  'while rival filmmaker period pieces still very much worth seeing',
#  'still very much worth',
#  'very much worth',
#  'oddly humorous',
#  'Evokes 19th century with subtlety that object lesson period filmmaking',
#  'three actresses simply dazzling particularly Balk finally been given part worthy considerable talents',
#  'simply dazzling particularly Balk finally been given part worthy considerable talents',
#  'dazzling',
#  'finally been given part worthy considerable talents',
#  'given part worthy considerable talents',
#  'considerable talents',
#  'considerable talents',
#  'captivated moods subtly transformed star still wonder Paul Thomas Anderson ever inclination make most sincere artful movie which Adam Sandler will probably ever appear',
#  'captivated moods subtly transformed star still wonder Paul Thomas Anderson ever inclination make most sincere artful movie which Adam Sandler will probably ever appear',
#  'captivated moods subtly transformed star',
#  'captivated moods subtly transformed star',
#  'captivated',
#  'captivated',
#  'Paul Thomas Anderson ever inclination make most sincere artful movie which Adam Sandler will probably ever appear',
#  'make most sincere artful movie which Adam Sandler will probably ever appear',
#  'make most sincere artful movie which Adam Sandler will probably ever appear',
#  'most sincere artful movie',
#  'most sincere artful movie',
#  'vivid portrait woman consumed lust love crushed betrayal that conjures intoxicating fumes emotional ghosts freshly painted Rembrandt',
#  'freshly painted Rembrandt',
#  'Brings spectacular completion most complex generous subversive artworks last decade',
#  'Brings spectacular completion most complex generous subversive artworks last decade',
#  'spectacular completion',
#  'most complex generous subversive artworks last decade',
#  'most complex generous subversive artworks last decade',
#  'generous subversive artworks',
#  'obvious rapport with actors',
#  'striking style',
#  'definitely director watch',
#  'definitely director watch',
#  'impressive achievement',
#  'impressive achievement',
#  'beautiful movement inside information',
#  'beautiful movement inside information',
#  'Dong makes valiant effort understand everyone point view does such good that Family Fundamentals gets riled',
#  'Dong makes valiant effort understand everyone point view does such good that Family Fundamentals gets riled',
#  'Dong makes valiant effort understand everyone point view',
#  'valiant effort understand everyone point view',
#  'does such good that Family Fundamentals gets riled',
#  'such good',
#  'good',
#  'good',
#  'Family Fundamentals gets riled',
#  'Light candles bring cake fret about calories because there precious little substance Birthday Girl simply surprisingly nice light treat',
#  'simply surprisingly nice light treat',
#  'debut director Washington sure hand',
#  'Washington sure hand',
#  'makes most purely enjoyable satisfying evenings movies while',
#  'makes most purely enjoyable satisfying evenings movies while',
#  'makes most purely enjoyable satisfying evenings movies while',
#  'makes most purely enjoyable satisfying evenings movies while',
#  'makes most purely enjoyable satisfying evenings movies while',
#  'most purely enjoyable satisfying evenings movies while',
#  'most purely enjoyable satisfying evenings movies while',
#  'most purely enjoyable satisfying evenings movies while',
#  'most purely enjoyable satisfying evenings movies while',
#  'most purely enjoyable satisfying evenings movies',
#  'most purely enjoyable satisfying evenings',
#  'most purely enjoyable satisfying evenings',
#  'most purely enjoyable satisfying',
#  'most purely enjoyable',
#  'even lesser works outshine best some directors',
#  'touching reflection aging suffering prospect death',
#  'glorious spectacle like those Griffith made early days silent film',
#  'glorious spectacle',
#  'glorious spectacle',
#  'glorious',
#  'year greatest adventure Jackson limited enthusiastic adaptation made literature literal without killing soul feat thinking person bound appreciate',
#  'year greatest adventure Jackson limited enthusiastic adaptation made literature literal without killing soul feat thinking person bound appreciate',
#  'year greatest adventure',
#  'year greatest adventure',
#  'year greatest adventure',
#  'greatest adventure',
#  'made literature literal without killing soul feat thinking person bound appreciate',
#  'feat thinking person bound appreciate',
#  'When said done loves them pieces',
#  'film that will probably please people',
#  'beautiful',
#  'genial decent',
#  'interesting likable',
#  'interesting',
#  'happiness',
#  'This movie cherished',
#  'cherished',
#  'Bard black comedy Willie would have loved',
#  'have loved',
#  'loved',
#  'loved',
#  'While Tattoo borrows heavily from both Seven Silence Lambs manages maintain both level sophisticated intrigue humanscale characters that suck audience',
#  'manages maintain both level sophisticated intrigue humanscale characters that suck audience',
#  'manages maintain both level sophisticated intrigue humanscale characters that suck audience',
#  'determined treat characters weak strong fallible human beings caricatures carefully delineate cost inevitable conflicts between human urges institution concerned with selfpreservation',
#  'Scratch great full kind energy documenting',
#  'great full kind energy documenting',
#  'great full kind energy documenting',
#  'great full kind energy documenting',
#  'great',
#  'meaningful historical context',
#  'astonishing',
#  'real winner smart funny subtle resonant',
#  'real winner smart funny subtle resonant',
#  'real winner',
#  'real winner',
#  'real winner',
#  'winner',
#  'smart funny subtle resonant',
#  'greatesthits reel',
#  'Jones makes great impression writerdirector this little million charmer which cuttingedge indie filmmaking huge heart',
#  'makes great impression',
#  'great impression',
#  'cuttingedge indie filmmaking',
#  'cuttingedge',
#  'huge heart',
#  'watch these together again York minute',
#  'Ferrara best film years',
#  'Ferrara best film years',
#  'best film',
#  'Poetry motion captured film',
#  'Poetry motion',
#  'mostly magnificent directorial career Clint Eastwood efficiently minimalist style',
#  'mostly magnificent directorial career',
#  'mostly magnificent directorial career',
#  'mostly magnificent directorial career',
#  'magnificent directorial career',
#  'magnificent',
#  'Hutchins talented enough charismatic enough make care about Zelda ultimate fate',
#  'talented enough charismatic enough make care about Zelda ultimate fate',
#  'talented enough',
#  'Successfully blended satire high camp another sexual taboo into really funny movie',
#  'really funny movie',
#  'really funny movie',
#  'panAmerican movie with moments genuine insight into urban heart',
#  'with moments genuine insight into urban heart',
#  'genuine insight into urban heart',
#  'genuine insight into urban heart',
#  'genuine insight',
#  'genuine',
#  'superior plotline',
#  'superior plotline',
#  'more than moments that insightful enough fondly remembered endlessly challenging maze moviegoing',
#  'that insightful enough fondly remembered endlessly challenging maze moviegoing',
#  'Perhaps best sports movie ever seen',
#  'best sports movie ever seen',
#  'best sports movie ever seen',
#  'best sports movie',
#  'best sports movie',
#  'largeframe IMAX camera lends itself beautifully filming teeming life reefs making this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'lends itself beautifully filming teeming life reefs making this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'lends itself beautifully filming teeming life reefs making this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'itself beautifully filming teeming life reefs making this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'filming teeming life reefs making this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'filming teeming life reefs making this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'this gorgeous film must everyone from junior scientists grownup fish lovers',
#  'gorgeous film must everyone from junior scientists grownup fish lovers',
#  'film must everyone from junior scientists grownup fish lovers',
#  'film must everyone from junior scientists',
#  'film must',
#  'keep wide awake very tense',
#  'keep wide awake',
#  'this charmer spirit that denied',
#  'spirit that denied',
#  'Though will argue that ranks with best Herzog works Invincible shows back form with astoundingly rich film',
#  'that ranks with best Herzog works',
#  'ranks with best Herzog works',
#  'ranks with best Herzog works',
#  'with best Herzog works',
#  'best Herzog works',
#  'best',
#  'Invincible shows back form with astoundingly rich film',
#  'Invincible shows back form with astoundingly rich film',
#  'shows back form with astoundingly rich film',
#  'back form with astoundingly rich film',
#  'astoundingly rich film',
#  'astoundingly rich film',
#  'astoundingly rich',
#  'From deceptively simple premise this deeply moving French drama develops startling story that works both detailed personal portrait rather frightening examination modern times',
#  'labour love',
#  'stylish cast some clever scripting solutions',
#  'stylish cast',
#  'with considerable appeal',
#  'finding their',
#  'movie that accomplishes much that viewing possibly enough',
#  'movie that accomplishes much that viewing possibly enough',
#  'movie that accomplishes much that viewing possibly enough',
#  'accomplishes much that viewing possibly enough',
#  'much that viewing possibly enough',
#  'your vintage wines watch your Merchant Ivory productions settle nice cool glass iced Jerry Bruckheimer flick week',
#  'Just labour involved creating layered richness imagery this chiaroscuro madness light astonishing',
#  'creating layered richness imagery this chiaroscuro madness light',
#  'Sometimes',
#  'remarkable feat',
#  'topnotch foursome',
#  'topnotch',
#  'there great deal',
#  'great deal',
#  'great deal',
#  'great deal',
#  'power fantasy',
#  'superdooperadorability intact',
#  'worthy substitute',
#  'most sparkling',
#  'most sparkling',
#  'laughoutloud bits',
#  'movie trove delights',
#  'trove delights',
#  'might have been more daring surprising American movies year',
#  'might have been more daring surprising American movies year',
#  'have been more daring surprising American movies year',
#  'been more daring surprising American movies year',
#  'wellexecuted spythriller',
#  'wellexecuted spythriller',
#  'wellexecuted',
#  'unfolds Sand masculine persona with love life beauty takes form',
#  'most aggressive most sincere',
#  'take movies storm',
#  'lying said ribcage ache Kung',
#  'effecting change inspiring hope',
#  'developed characters much',
#  'that really funny',
#  'immensely appealing couple',
#  'immensely appealing couple',
#  'immensely appealing',
#  'check',
#  'very attractive about this movie',
#  'actors good Pauline Paulette Groen described Belgium national treasure especially terrific Pauline',
#  'Groen described Belgium national treasure especially terrific Pauline',
#  'especially terrific Pauline',
#  'remarkably alluring film',
#  'remarkably alluring film',
#  'alluring',
#  'cheery',
#  'More than anything else Kissing Jessica Stein injects freshness spirit into romantic comedy genre which been held hostage generic scripts that seek remake Sleepless Seattle again again',
#  'Kissing Jessica Stein injects freshness spirit into romantic comedy genre which been held hostage generic scripts that seek remake Sleepless Seattle again again',
#  'Kissing Jessica Stein injects freshness spirit into romantic comedy genre which been held hostage generic scripts that seek remake Sleepless Seattle again again',
#  'injects freshness spirit into romantic comedy genre which been held hostage generic scripts that seek remake Sleepless Seattle again again',
#  'injects freshness spirit',
#  'Fast funny action cartoon that suspenseful enough older kids scary schoolage crowd',
#  'only better than predecessor rate most magical most family fare this recent holiday season',
#  'rate most magical most family fare this recent holiday season',
#  'rate most magical most family fare this recent holiday season',
#  'rate most magical most family fare this recent holiday season',
#  'rate most magical most family fare this recent holiday season',
#  ...]

# %%
pos_total_words = ' '.join(pos_text_list)
pos_total_words = word_tokenize(pos_total_words)

pos_frequency = FreqDist(pos_total_words)

# %%
pos_20 = px.bar(pd.DataFrame(pos_frequency, index=[0]).T.sort_values(by=[0], ascending=False).head(20))
pos_20.show()
# Out:
# <div>                            <div id="40aa9759-74ec-4f51-9068-c3750eb9f296" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40aa9759-74ec-4f51-9068-c3750eb9f296")) {                    Plotly.newPlot(                        "40aa9759-74ec-4f51-9068-c3750eb9f296",                        [{"alignmentgroup":"True","hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["that","film","with","movie","this","most","best","funny","good","from","performances","story","comedy","about","performance","great","than","more","have","work"],"xaxis":"x","y":[1248,930,912,564,473,439,364,341,281,270,253,236,229,228,219,210,209,209,199,195],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"c ...

# %% [markdown]
# ### 긍정적인 감성 표현에 자주 사용되는 bigram 단어
#
# > n-gram : 단어마다 그 단어 포함 뒤로 n개만큼의 단어를 한 묶음으로 보고 이를 하나의 토큰으로 간주 하는 것.
# - n=1 : unigrams
# - n=2 : bigrams
# - n=3 : trigrams
# - n=4 : ngrams

# %%
text_list = []
